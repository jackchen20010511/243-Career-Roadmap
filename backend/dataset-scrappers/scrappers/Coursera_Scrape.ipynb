# %% [markdown]
# ## Coursera

# %%
import os
import time
import urllib.parse
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import json

# %%
options = webdriver.ChromeOptions()
options.add_argument("--lang=en-US")  # Force browser to load English
options.add_argument("--headless")  # Run in headless mode (no GUI)
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920,1080")
options.add_argument("--log-level=3")  # Suppress logs

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# --------------------------------------------------------------------------------------------------------------------------
# Search skills: what skills do you want to get course data on
# --------------------------------------------------------------------------------------------------------------------------
# Specify the path to the file containing the extracted skills

with open("job_domain_skills.json", "r", encoding="utf-8") as f:
    job_domain_skills = json.load(f)

url_list = []

for job, skills in job_domain_skills.items():
    for skill in skills:
        url = "https://www.coursera.org/search?query="+urllib.parse.quote(f"{skill} {skill} {job}")
        url_list.append([job, skill, url])

latest_url_index = 0

data_folder = "coursera_data"
os.makedirs(data_folder, exist_ok=True)  # Ensure folder exists

# Function to scroll down to load dynamic content
def scroll_page(n,target_class):
    """scroll page utill there are n course cards or no new contents are loaded"""
    num_courses = len(driver.find_elements(By.CLASS_NAME, target_class))
    no_new_scroll = 0
    print(f"Scrolling and get num_course: {num_courses}",end="")
    while num_courses < n and no_new_scroll < 10:  # Adjust range as needed
        driver.execute_script("window.scrollBy(0, 800);")
        time.sleep(0.5)# Wait for content to load
        new_num_courses = len(driver.find_elements(By.CLASS_NAME, target_class))
        print(f"-{new_num_courses}",end="")
        if new_num_courses > num_courses:
            no_new_scroll = 0
            num_courses = new_num_courses
        else:
            no_new_scroll += 1
    print('')

data = []
for idx, ls in enumerate(url_list[latest_url_index:]):
    job = ls[0]
    skill = ls[1]
    url = ls[2]
    print(job, skill)
    try:
        print(f"Scraping URL: {url}")
        driver.get(url)
        while not driver.page_source:
            time.sleep(3)# Wait for initial load
        
        # Define the class name of the target div (Update based on actual class)
        target_class = "cds-ProductCard-gridCard"  # Example class, adjust based on inspection
        
        # ------------------------------------------------------------------------------------------------------------------
        # Scroll page; change number of courses you want to scroll and scrape for each skill
        # ------------------------------------------------------------------------------------------------------------------
        scroll_page(20,target_class)

    except Exception as e:
        print(f"Failed to scrape {url}: {e}")

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find all product containers
    course_divs = soup.find_all('div', class_= "cds-ProductCard-gridCard")
    print(f"Course divs found {len(course_divs)}")
    
    # Extract information
    course = []
    for div in course_divs:
        if div:
            # Extract course link
            link_div = div.find("a", class_="cds-119 cds-113 cds-115 cds-CommonCard-titleLink css-vflzcf cds-142")
            head = "https://www.coursera.org"
            link = link_div['href'] if link_div else None
            link = head + link if link else None

            # Extract course image link
            img_div = div.find("div", class_="cds-CommonCard-previewImage")
            img_tag = img_div.find("img") if img_div else None
            img_link = img_tag['src'] if img_tag else None

            # Extract partner name
            partner_tag = div.find('p', class_='cds-ProductCard-partnerNames css-vac8rf')
            partner = partner_tag.text.strip() if partner_tag else None

            # Extract course title
            title_tag = div.find('h3', class_='cds-CommonCard-title css-6ecy9b')
            title = title_tag.text.strip() if title_tag else None

            # Extract skills
            skill_div = div.find("div", class_="cds-ProductCard-body")
            skill_tag = skill_div.find('p', class_="css-vac8rf") if skill_div else None
            text = skill_tag.find_all(string=True, recursive=False) if skill_tag else None
            skills = [word.strip() for word in "".join(text).strip().split(",")] if text else None


            # Extract rating
            rating_tag = div.find('span', class_='css-6ecy9b')
            rating = float(rating_tag.text.strip()) if rating_tag else None

            def convert_reviews(text):
                text = text.replace("reviews", "").strip()  # Remove "reviews" and trim spaces
                if "K" in text:
                    return int(float(text.replace("K", "")) * 1000)  # Convert "2.1K" → 2100
                return int(text)  # Convert normal numbers

            # Extract number of reviews
            num_review_div = div.find("div", class_="cds-CommonCard-ratings")
            num_review_tag = num_review_div.find('div', class_='css-vac8rf') if num_review_div else None
            num_review = convert_reviews(num_review_tag.text.strip()) if num_review_tag else None

            # Extract course info
            info_div = div.find("div", class_="cds-CommonCard-metadata")
            info_tag = info_div.find('p', class_='css-vac8rf') if info_div else None
            info = info_tag.text.strip() if info_tag else None
            # Allowed difficulty levels
            difficulty_levels = {"Beginner", "Intermediate", "Advanced", "Mixed"}
            # Duration keywords
            duration_units = {"Weeks", "Months", "Hours"}
            def extract_info(text):
                parts = [part.strip() for part in text.split("·")]  # Split by '·' and clean spaces
                # Default buckets
                difficulty, course_type, duration = None, None, None
                for part in parts:
                    if part in difficulty_levels:
                        difficulty = part  # Assign as difficulty
                    elif any(unit in part for unit in duration_units):  # Check for duration keywords
                        duration = part
                    else:
                        course_type = part  # Assign as type if it's neither difficulty nor duration
                return difficulty, course_type, duration
            difficulty, course_type, duration = extract_info(info) if info else (None, None, None)
            
            # Append extracted data
            course.append({
                'skill': skill,
                'link': link,
                'image_link': img_link,
                'partner': partner,
                'title': title,
                'course_skill': skills,
                'rating': rating,
                'num_review': num_review,
                'difficulty': difficulty,
                'course_type': course_type,
                'duration': duration
            })
    df = pd.DataFrame(course)
    skillname = skill.replace("/", "_").replace("*", "_")
    csv_path = os.path.join(data_folder, f"{job}_{skillname}.csv")
    df.to_csv(csv_path, index=False)
    print(f"{skillname}.csv saved at: {csv_path}")
    print(f"-----------------------------------------------Scraping Complete Index ({latest_url_index+idx}/{len(url_list)-1})-----------------------------------------------")
            
# Close the driver after scraping
driver.quit()
# Out:
# Business Analyst .net
# Scraping URL: https://www.coursera.org/search?query=.net%20.net%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# .net.csv saved at: coursera_data\Business Analyst_.net.csv
# -----------------------------------------------Scraping Complete Index (0/2666)-----------------------------------------------
# Business Analyst .net frameworks
# Scraping URL: https://www.coursera.org/search?query=.net%20frameworks%20.net%20frameworks%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# .net frameworks.csv saved at: coursera_data\Business Analyst_.net frameworks.csv
# -----------------------------------------------Scraping Complete Index (1/2666)-----------------------------------------------
# Business Analyst a/b testing
# Scraping URL: https://www.coursera.org/search?query=a/b%20testing%20a/b%20testing%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# a_b testing.csv saved at: coursera_data\Business Analyst_a_b testing.csv
# -----------------------------------------------Scraping Complete Index (2/2666)-----------------------------------------------
# Business Analyst abap
# Scraping URL: https://www.coursera.org/search?query=abap%20abap%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# abap.csv saved at: coursera_data\Business Analyst_abap.csv
# -----------------------------------------------Scraping Complete Index (3/2666)-----------------------------------------------
# Business Analyst access
# Scraping URL: https://www.coursera.org/search?query=access%20access%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# access.csv saved at: coursera_data\Business Analyst_access.csv
# -----------------------------------------------Scraping Complete Index (4/2666)-----------------------------------------------
# Business Analyst active directory
# Scraping URL: https://www.coursera.org/search?query=active%20directory%20active%20directory%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# active directory.csv saved at: coursera_data\Business Analyst_active directory.csv
# -----------------------------------------------Scraping Complete Index (5/2666)-----------------------------------------------
# Business Analyst agile
# Scraping URL: https://www.coursera.org/search?query=agile%20agile%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# agile.csv saved at: coursera_data\Business Analyst_agile.csv
# -----------------------------------------------Scraping Complete Index (6/2666)-----------------------------------------------
# Business Analyst agile development
# Scraping URL: https://www.coursera.org/search?query=agile%20development%20agile%20development%20Business%20Analyst
# Scrolling and get num_course: 12-12-24
# Course divs found 24
# agile development.csv saved at: coursera_data\Business Analyst_agile development.csv
# -----------------------------------------------Scraping Complete Index (7/2666)-----------------------------------------------
# Business Analyst alteryx
# Scraping URL: https://www.coursera.org/search?query=alteryx%20alteryx%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# alteryx.csv saved at: coursera_data\Business Analyst_alteryx.csv
# -----------------------------------------------Scraping Complete Index (8/2666)-----------------------------------------------
# Business Analyst analytical skills
# Scraping URL: https://www.coursera.org/search?query=analytical%20skills%20analytical%20skills%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# analytical skills.csv saved at: coursera_data\Business Analyst_analytical skills.csv
# -----------------------------------------------Scraping Complete Index (9/2666)-----------------------------------------------
# Business Analyst analytics
# Scraping URL: https://www.coursera.org/search?query=analytics%20analytics%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# analytics.csv saved at: coursera_data\Business Analyst_analytics.csv
# -----------------------------------------------Scraping Complete Index (10/2666)-----------------------------------------------
# Business Analyst angular
# Scraping URL: https://www.coursera.org/search?query=angular%20angular%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# angular.csv saved at: coursera_data\Business Analyst_angular.csv
# -----------------------------------------------Scraping Complete Index (11/2666)-----------------------------------------------
# Business Analyst api
# Scraping URL: https://www.coursera.org/search?query=api%20api%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# api.csv saved at: coursera_data\Business Analyst_api.csv
# -----------------------------------------------Scraping Complete Index (12/2666)-----------------------------------------------
# Business Analyst apo - advanced planning and optimization
# Scraping URL: https://www.coursera.org/search?query=apo%20-%20advanced%20planning%20and%20optimization%20apo%20-%20advanced%20planning%20and%20optimization%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# apo - advanced planning and optimization.csv saved at: coursera_data\Business Analyst_apo - advanced planning and optimization.csv
# -----------------------------------------------Scraping Complete Index (13/2666)-----------------------------------------------
# Business Analyst ariba
# Scraping URL: https://www.coursera.org/search?query=ariba%20ariba%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ariba.csv saved at: coursera_data\Business Analyst_ariba.csv
# -----------------------------------------------Scraping Complete Index (14/2666)-----------------------------------------------
# Business Analyst asp.net
# Scraping URL: https://www.coursera.org/search?query=asp.net%20asp.net%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# asp.net.csv saved at: coursera_data\Business Analyst_asp.net.csv
# -----------------------------------------------Scraping Complete Index (15/2666)-----------------------------------------------
# Business Analyst aws
# Scraping URL: https://www.coursera.org/search?query=aws%20aws%20Business%20Analyst
# Scrolling and get num_course: 12-12-24
# Course divs found 24
# aws.csv saved at: coursera_data\Business Analyst_aws.csv
# -----------------------------------------------Scraping Complete Index (16/2666)-----------------------------------------------
# Business Analyst azure
# Scraping URL: https://www.coursera.org/search?query=azure%20azure%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# azure.csv saved at: coursera_data\Business Analyst_azure.csv
# -----------------------------------------------Scraping Complete Index (17/2666)-----------------------------------------------
# Business Analyst bi tool
# Scraping URL: https://www.coursera.org/search?query=bi%20tool%20bi%20tool%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-12-24
# Course divs found 24
# bi tool.csv saved at: coursera_data\Business Analyst_bi tool.csv
# -----------------------------------------------Scraping Complete Index (18/2666)-----------------------------------------------
# Business Analyst big data
# Scraping URL: https://www.coursera.org/search?query=big%20data%20big%20data%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# big data.csv saved at: coursera_data\Business Analyst_big data.csv
# -----------------------------------------------Scraping Complete Index (19/2666)-----------------------------------------------
# Business Analyst business analysis
# Scraping URL: https://www.coursera.org/search?query=business%20analysis%20business%20analysis%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# business analysis.csv saved at: coursera_data\Business Analyst_business analysis.csv
# -----------------------------------------------Scraping Complete Index (20/2666)-----------------------------------------------
# Business Analyst business analyst
# Scraping URL: https://www.coursera.org/search?query=business%20analyst%20business%20analyst%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-24
# Course divs found 24
# business analyst.csv saved at: coursera_data\Business Analyst_business analyst.csv
# -----------------------------------------------Scraping Complete Index (21/2666)-----------------------------------------------
# Business Analyst business intelligence
# Scraping URL: https://www.coursera.org/search?query=business%20intelligence%20business%20intelligence%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# business intelligence.csv saved at: coursera_data\Business Analyst_business intelligence.csv
# -----------------------------------------------Scraping Complete Index (22/2666)-----------------------------------------------
# Business Analyst business intelligence tools
# Scraping URL: https://www.coursera.org/search?query=business%20intelligence%20tools%20business%20intelligence%20tools%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# business intelligence tools.csv saved at: coursera_data\Business Analyst_business intelligence tools.csv
# -----------------------------------------------Scraping Complete Index (23/2666)-----------------------------------------------
# Business Analyst business object
# Scraping URL: https://www.coursera.org/search?query=business%20object%20business%20object%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# business object.csv saved at: coursera_data\Business Analyst_business object.csv
# -----------------------------------------------Scraping Complete Index (24/2666)-----------------------------------------------
# Business Analyst c#
# Scraping URL: https://www.coursera.org/search?query=c%23%20c%23%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# c#.csv saved at: coursera_data\Business Analyst_c#.csv
# -----------------------------------------------Scraping Complete Index (25/2666)-----------------------------------------------
# Business Analyst c++
# Scraping URL: https://www.coursera.org/search?query=c%2B%2B%20c%2B%2B%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# c++.csv saved at: coursera_data\Business Analyst_c++.csv
# -----------------------------------------------Scraping Complete Index (26/2666)-----------------------------------------------
# Business Analyst cassandra
# Scraping URL: https://www.coursera.org/search?query=cassandra%20cassandra%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# cassandra.csv saved at: coursera_data\Business Analyst_cassandra.csv
# -----------------------------------------------Scraping Complete Index (27/2666)-----------------------------------------------
# Business Analyst cissp
# Scraping URL: https://www.coursera.org/search?query=cissp%20cissp%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# cissp.csv saved at: coursera_data\Business Analyst_cissp.csv
# -----------------------------------------------Scraping Complete Index (28/2666)-----------------------------------------------
# Business Analyst cloud
# Scraping URL: https://www.coursera.org/search?query=cloud%20cloud%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# cloud.csv saved at: coursera_data\Business Analyst_cloud.csv
# -----------------------------------------------Scraping Complete Index (29/2666)-----------------------------------------------
# Business Analyst cloud based technologies
# Scraping URL: https://www.coursera.org/search?query=cloud%20based%20technologies%20cloud%20based%20technologies%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# cloud based technologies.csv saved at: coursera_data\Business Analyst_cloud based technologies.csv
# -----------------------------------------------Scraping Complete Index (30/2666)-----------------------------------------------
# Business Analyst cognos
# Scraping URL: https://www.coursera.org/search?query=cognos%20cognos%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# cognos.csv saved at: coursera_data\Business Analyst_cognos.csv
# -----------------------------------------------Scraping Complete Index (31/2666)-----------------------------------------------
# Business Analyst communication skills
# Scraping URL: https://www.coursera.org/search?query=communication%20skills%20communication%20skills%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# communication skills.csv saved at: coursera_data\Business Analyst_communication skills.csv
# -----------------------------------------------Scraping Complete Index (32/2666)-----------------------------------------------
# Business Analyst configuration
# Scraping URL: https://www.coursera.org/search?query=configuration%20configuration%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# configuration.csv saved at: coursera_data\Business Analyst_configuration.csv
# -----------------------------------------------Scraping Complete Index (33/2666)-----------------------------------------------
# Business Analyst configuration and design
# Scraping URL: https://www.coursera.org/search?query=configuration%20and%20design%20configuration%20and%20design%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# configuration and design.csv saved at: coursera_data\Business Analyst_configuration and design.csv
# -----------------------------------------------Scraping Complete Index (34/2666)-----------------------------------------------
# Business Analyst crm
# Scraping URL: https://www.coursera.org/search?query=crm%20crm%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# crm.csv saved at: coursera_data\Business Analyst_crm.csv
# -----------------------------------------------Scraping Complete Index (35/2666)-----------------------------------------------
# Business Analyst crystal reports
# Scraping URL: https://www.coursera.org/search?query=crystal%20reports%20crystal%20reports%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# crystal reports.csv saved at: coursera_data\Business Analyst_crystal reports.csv
# -----------------------------------------------Scraping Complete Index (36/2666)-----------------------------------------------
# Business Analyst css
# Scraping URL: https://www.coursera.org/search?query=css%20css%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# css.csv saved at: coursera_data\Business Analyst_css.csv
# -----------------------------------------------Scraping Complete Index (37/2666)-----------------------------------------------
# Business Analyst data analysis
# Scraping URL: https://www.coursera.org/search?query=data%20analysis%20data%20analysis%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data analysis.csv saved at: coursera_data\Business Analyst_data analysis.csv
# -----------------------------------------------Scraping Complete Index (38/2666)-----------------------------------------------
# Business Analyst data analytics
# Scraping URL: https://www.coursera.org/search?query=data%20analytics%20data%20analytics%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data analytics.csv saved at: coursera_data\Business Analyst_data analytics.csv
# -----------------------------------------------Scraping Complete Index (39/2666)-----------------------------------------------
# Business Analyst data governance
# Scraping URL: https://www.coursera.org/search?query=data%20governance%20data%20governance%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data governance.csv saved at: coursera_data\Business Analyst_data governance.csv
# -----------------------------------------------Scraping Complete Index (40/2666)-----------------------------------------------
# Business Analyst data integration
# Scraping URL: https://www.coursera.org/search?query=data%20integration%20data%20integration%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data integration.csv saved at: coursera_data\Business Analyst_data integration.csv
# -----------------------------------------------Scraping Complete Index (41/2666)-----------------------------------------------
# Business Analyst data mapping
# Scraping URL: https://www.coursera.org/search?query=data%20mapping%20data%20mapping%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data mapping.csv saved at: coursera_data\Business Analyst_data mapping.csv
# -----------------------------------------------Scraping Complete Index (42/2666)-----------------------------------------------
# Business Analyst data migration
# Scraping URL: https://www.coursera.org/search?query=data%20migration%20data%20migration%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data migration.csv saved at: coursera_data\Business Analyst_data migration.csv
# -----------------------------------------------Scraping Complete Index (43/2666)-----------------------------------------------
# Business Analyst data mining
# Scraping URL: https://www.coursera.org/search?query=data%20mining%20data%20mining%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data mining.csv saved at: coursera_data\Business Analyst_data mining.csv
# -----------------------------------------------Scraping Complete Index (44/2666)-----------------------------------------------
# Business Analyst data modeling
# Scraping URL: https://www.coursera.org/search?query=data%20modeling%20data%20modeling%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data modeling.csv saved at: coursera_data\Business Analyst_data modeling.csv
# -----------------------------------------------Scraping Complete Index (45/2666)-----------------------------------------------
# Business Analyst data quality
# Scraping URL: https://www.coursera.org/search?query=data%20quality%20data%20quality%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data quality.csv saved at: coursera_data\Business Analyst_data quality.csv
# -----------------------------------------------Scraping Complete Index (46/2666)-----------------------------------------------
# Business Analyst data science
# Scraping URL: https://www.coursera.org/search?query=data%20science%20data%20science%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data science.csv saved at: coursera_data\Business Analyst_data science.csv
# -----------------------------------------------Scraping Complete Index (47/2666)-----------------------------------------------
# Business Analyst data visualization
# Scraping URL: https://www.coursera.org/search?query=data%20visualization%20data%20visualization%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data visualization.csv saved at: coursera_data\Business Analyst_data visualization.csv
# -----------------------------------------------Scraping Complete Index (48/2666)-----------------------------------------------
# Business Analyst data warehouse
# Scraping URL: https://www.coursera.org/search?query=data%20warehouse%20data%20warehouse%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data warehouse.csv saved at: coursera_data\Business Analyst_data warehouse.csv
# -----------------------------------------------Scraping Complete Index (49/2666)-----------------------------------------------
# Business Analyst data warehousing
# Scraping URL: https://www.coursera.org/search?query=data%20warehousing%20data%20warehousing%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# data warehousing.csv saved at: coursera_data\Business Analyst_data warehousing.csv
# -----------------------------------------------Scraping Complete Index (50/2666)-----------------------------------------------
# Business Analyst database
# Scraping URL: https://www.coursera.org/search?query=database%20database%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# database.csv saved at: coursera_data\Business Analyst_database.csv
# -----------------------------------------------Scraping Complete Index (51/2666)-----------------------------------------------
# Business Analyst database concepts
# Scraping URL: https://www.coursera.org/search?query=database%20concepts%20database%20concepts%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-24
# Course divs found 24
# database concepts.csv saved at: coursera_data\Business Analyst_database concepts.csv
# -----------------------------------------------Scraping Complete Index (52/2666)-----------------------------------------------
# Business Analyst db2
# Scraping URL: https://www.coursera.org/search?query=db2%20db2%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# db2.csv saved at: coursera_data\Business Analyst_db2.csv
# -----------------------------------------------Scraping Complete Index (53/2666)-----------------------------------------------
# Business Analyst deep learning
# Scraping URL: https://www.coursera.org/search?query=deep%20learning%20deep%20learning%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# deep learning.csv saved at: coursera_data\Business Analyst_deep learning.csv
# -----------------------------------------------Scraping Complete Index (54/2666)-----------------------------------------------
# Business Analyst designing
# Scraping URL: https://www.coursera.org/search?query=designing%20designing%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# designing.csv saved at: coursera_data\Business Analyst_designing.csv
# -----------------------------------------------Scraping Complete Index (55/2666)-----------------------------------------------
# Business Analyst designing and prototyping
# Scraping URL: https://www.coursera.org/search?query=designing%20and%20prototyping%20designing%20and%20prototyping%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# designing and prototyping.csv saved at: coursera_data\Business Analyst_designing and prototyping.csv
# -----------------------------------------------Scraping Complete Index (56/2666)-----------------------------------------------
# Business Analyst devops
# Scraping URL: https://www.coursera.org/search?query=devops%20devops%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# devops.csv saved at: coursera_data\Business Analyst_devops.csv
# -----------------------------------------------Scraping Complete Index (57/2666)-----------------------------------------------
# Business Analyst dimensional modeling
# Scraping URL: https://www.coursera.org/search?query=dimensional%20modeling%20dimensional%20modeling%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# dimensional modeling.csv saved at: coursera_data\Business Analyst_dimensional modeling.csv
# -----------------------------------------------Scraping Complete Index (58/2666)-----------------------------------------------
# Business Analyst documentation
# Scraping URL: https://www.coursera.org/search?query=documentation%20documentation%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# documentation.csv saved at: coursera_data\Business Analyst_documentation.csv
# -----------------------------------------------Scraping Complete Index (59/2666)-----------------------------------------------
# Business Analyst edi
# Scraping URL: https://www.coursera.org/search?query=edi%20edi%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# edi.csv saved at: coursera_data\Business Analyst_edi.csv
# -----------------------------------------------Scraping Complete Index (60/2666)-----------------------------------------------
# Business Analyst erp
# Scraping URL: https://www.coursera.org/search?query=erp%20erp%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# erp.csv saved at: coursera_data\Business Analyst_erp.csv
# -----------------------------------------------Scraping Complete Index (61/2666)-----------------------------------------------
# Business Analyst etl
# Scraping URL: https://www.coursera.org/search?query=etl%20etl%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# etl.csv saved at: coursera_data\Business Analyst_etl.csv
# -----------------------------------------------Scraping Complete Index (62/2666)-----------------------------------------------
# Business Analyst etl development
# Scraping URL: https://www.coursera.org/search?query=etl%20development%20etl%20development%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# etl development.csv saved at: coursera_data\Business Analyst_etl development.csv
# -----------------------------------------------Scraping Complete Index (63/2666)-----------------------------------------------
# Business Analyst etl tool
# Scraping URL: https://www.coursera.org/search?query=etl%20tool%20etl%20tool%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# etl tool.csv saved at: coursera_data\Business Analyst_etl tool.csv
# -----------------------------------------------Scraping Complete Index (64/2666)-----------------------------------------------
# Business Analyst ewm - extended warehouse management
# Scraping URL: https://www.coursera.org/search?query=ewm%20-%20extended%20warehouse%20management%20ewm%20-%20extended%20warehouse%20management%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ewm - extended warehouse management.csv saved at: coursera_data\Business Analyst_ewm - extended warehouse management.csv
# -----------------------------------------------Scraping Complete Index (65/2666)-----------------------------------------------
# Business Analyst excel
# Scraping URL: https://www.coursera.org/search?query=excel%20excel%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# excel.csv saved at: coursera_data\Business Analyst_excel.csv
# -----------------------------------------------Scraping Complete Index (66/2666)-----------------------------------------------
# Business Analyst financial modeling
# Scraping URL: https://www.coursera.org/search?query=financial%20modeling%20financial%20modeling%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# financial modeling.csv saved at: coursera_data\Business Analyst_financial modeling.csv
# -----------------------------------------------Scraping Complete Index (67/2666)-----------------------------------------------
# Business Analyst functional specification
# Scraping URL: https://www.coursera.org/search?query=functional%20specification%20functional%20specification%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# functional specification.csv saved at: coursera_data\Business Analyst_functional specification.csv
# -----------------------------------------------Scraping Complete Index (68/2666)-----------------------------------------------
# Business Analyst git
# Scraping URL: https://www.coursera.org/search?query=git%20git%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# git.csv saved at: coursera_data\Business Analyst_git.csv
# -----------------------------------------------Scraping Complete Index (69/2666)-----------------------------------------------
# Business Analyst google analytics
# Scraping URL: https://www.coursera.org/search?query=google%20analytics%20google%20analytics%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# google analytics.csv saved at: coursera_data\Business Analyst_google analytics.csv
# -----------------------------------------------Scraping Complete Index (70/2666)-----------------------------------------------
# Business Analyst hadoop
# Scraping URL: https://www.coursera.org/search?query=hadoop%20hadoop%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-24
# Course divs found 24
# hadoop.csv saved at: coursera_data\Business Analyst_hadoop.csv
# -----------------------------------------------Scraping Complete Index (71/2666)-----------------------------------------------
# Business Analyst hana
# Scraping URL: https://www.coursera.org/search?query=hana%20hana%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-12-12-24
# Course divs found 24
# hana.csv saved at: coursera_data\Business Analyst_hana.csv
# -----------------------------------------------Scraping Complete Index (72/2666)-----------------------------------------------
# Business Analyst hibernate
# Scraping URL: https://www.coursera.org/search?query=hibernate%20hibernate%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# hibernate.csv saved at: coursera_data\Business Analyst_hibernate.csv
# -----------------------------------------------Scraping Complete Index (73/2666)-----------------------------------------------
# Business Analyst hive
# Scraping URL: https://www.coursera.org/search?query=hive%20hive%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# hive.csv saved at: coursera_data\Business Analyst_hive.csv
# -----------------------------------------------Scraping Complete Index (74/2666)-----------------------------------------------
# Business Analyst html
# Scraping URL: https://www.coursera.org/search?query=html%20html%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# html.csv saved at: coursera_data\Business Analyst_html.csv
# -----------------------------------------------Scraping Complete Index (75/2666)-----------------------------------------------
# Business Analyst html 5
# Scraping URL: https://www.coursera.org/search?query=html%205%20html%205%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# html 5.csv saved at: coursera_data\Business Analyst_html 5.csv
# -----------------------------------------------Scraping Complete Index (76/2666)-----------------------------------------------
# Business Analyst html5
# Scraping URL: https://www.coursera.org/search?query=html5%20html5%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-12-12-24
# Course divs found 24
# html5.csv saved at: coursera_data\Business Analyst_html5.csv
# -----------------------------------------------Scraping Complete Index (77/2666)-----------------------------------------------
# Business Analyst ibp - integrated business planning
# Scraping URL: https://www.coursera.org/search?query=ibp%20-%20integrated%20business%20planning%20ibp%20-%20integrated%20business%20planning%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ibp - integrated business planning.csv saved at: coursera_data\Business Analyst_ibp - integrated business planning.csv
# -----------------------------------------------Scraping Complete Index (78/2666)-----------------------------------------------
# Business Analyst informatica
# Scraping URL: https://www.coursera.org/search?query=informatica%20informatica%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# informatica.csv saved at: coursera_data\Business Analyst_informatica.csv
# -----------------------------------------------Scraping Complete Index (79/2666)-----------------------------------------------
# Business Analyst infrastructure
# Scraping URL: https://www.coursera.org/search?query=infrastructure%20infrastructure%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# infrastructure.csv saved at: coursera_data\Business Analyst_infrastructure.csv
# -----------------------------------------------Scraping Complete Index (80/2666)-----------------------------------------------
# Business Analyst integration
# Scraping URL: https://www.coursera.org/search?query=integration%20integration%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# integration.csv saved at: coursera_data\Business Analyst_integration.csv
# -----------------------------------------------Scraping Complete Index (81/2666)-----------------------------------------------
# Business Analyst itil
# Scraping URL: https://www.coursera.org/search?query=itil%20itil%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# itil.csv saved at: coursera_data\Business Analyst_itil.csv
# -----------------------------------------------Scraping Complete Index (82/2666)-----------------------------------------------
# Business Analyst java
# Scraping URL: https://www.coursera.org/search?query=java%20java%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# java.csv saved at: coursera_data\Business Analyst_java.csv
# -----------------------------------------------Scraping Complete Index (83/2666)-----------------------------------------------
# Business Analyst jira
# Scraping URL: https://www.coursera.org/search?query=jira%20jira%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# jira.csv saved at: coursera_data\Business Analyst_jira.csv
# -----------------------------------------------Scraping Complete Index (84/2666)-----------------------------------------------
# Business Analyst jquery
# Scraping URL: https://www.coursera.org/search?query=jquery%20jquery%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# jquery.csv saved at: coursera_data\Business Analyst_jquery.csv
# -----------------------------------------------Scraping Complete Index (85/2666)-----------------------------------------------
# Business Analyst js
# Scraping URL: https://www.coursera.org/search?query=js%20js%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# js.csv saved at: coursera_data\Business Analyst_js.csv
# -----------------------------------------------Scraping Complete Index (86/2666)-----------------------------------------------
# Business Analyst kafka
# Scraping URL: https://www.coursera.org/search?query=kafka%20kafka%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# kafka.csv saved at: coursera_data\Business Analyst_kafka.csv
# -----------------------------------------------Scraping Complete Index (87/2666)-----------------------------------------------
# Business Analyst kubernetes
# Scraping URL: https://www.coursera.org/search?query=kubernetes%20kubernetes%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# kubernetes.csv saved at: coursera_data\Business Analyst_kubernetes.csv
# -----------------------------------------------Scraping Complete Index (88/2666)-----------------------------------------------
# Business Analyst linux
# Scraping URL: https://www.coursera.org/search?query=linux%20linux%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-12-12-12-24
# Course divs found 24
# linux.csv saved at: coursera_data\Business Analyst_linux.csv
# -----------------------------------------------Scraping Complete Index (89/2666)-----------------------------------------------
# Business Analyst machine learning
# Scraping URL: https://www.coursera.org/search?query=machine%20learning%20machine%20learning%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# machine learning.csv saved at: coursera_data\Business Analyst_machine learning.csv
# -----------------------------------------------Scraping Complete Index (90/2666)-----------------------------------------------
# Business Analyst market research
# Scraping URL: https://www.coursera.org/search?query=market%20research%20market%20research%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# market research.csv saved at: coursera_data\Business Analyst_market research.csv
# -----------------------------------------------Scraping Complete Index (91/2666)-----------------------------------------------
# Business Analyst mdx
# Scraping URL: https://www.coursera.org/search?query=mdx%20mdx%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# mdx.csv saved at: coursera_data\Business Analyst_mdx.csv
# -----------------------------------------------Scraping Complete Index (92/2666)-----------------------------------------------
# Business Analyst mes - manufacturing execution system
# Scraping URL: https://www.coursera.org/search?query=mes%20-%20manufacturing%20execution%20system%20mes%20-%20manufacturing%20execution%20system%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# mes - manufacturing execution system.csv saved at: coursera_data\Business Analyst_mes - manufacturing execution system.csv
# -----------------------------------------------Scraping Complete Index (93/2666)-----------------------------------------------
# Business Analyst microsoft access
# Scraping URL: https://www.coursera.org/search?query=microsoft%20access%20microsoft%20access%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft access.csv saved at: coursera_data\Business Analyst_microsoft access.csv
# -----------------------------------------------Scraping Complete Index (94/2666)-----------------------------------------------
# Business Analyst microsoft excel
# Scraping URL: https://www.coursera.org/search?query=microsoft%20excel%20microsoft%20excel%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft excel.csv saved at: coursera_data\Business Analyst_microsoft excel.csv
# -----------------------------------------------Scraping Complete Index (95/2666)-----------------------------------------------
# Business Analyst microsoft office
# Scraping URL: https://www.coursera.org/search?query=microsoft%20office%20microsoft%20office%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft office.csv saved at: coursera_data\Business Analyst_microsoft office.csv
# -----------------------------------------------Scraping Complete Index (96/2666)-----------------------------------------------
# Business Analyst microsoft office products
# Scraping URL: https://www.coursera.org/search?query=microsoft%20office%20products%20microsoft%20office%20products%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-12-24
# Course divs found 24
# microsoft office products.csv saved at: coursera_data\Business Analyst_microsoft office products.csv
# -----------------------------------------------Scraping Complete Index (97/2666)-----------------------------------------------
# Business Analyst microsoft office suite
# Scraping URL: https://www.coursera.org/search?query=microsoft%20office%20suite%20microsoft%20office%20suite%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft office suite.csv saved at: coursera_data\Business Analyst_microsoft office suite.csv
# -----------------------------------------------Scraping Complete Index (98/2666)-----------------------------------------------
# Business Analyst microsoft powerpoint
# Scraping URL: https://www.coursera.org/search?query=microsoft%20powerpoint%20microsoft%20powerpoint%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft powerpoint.csv saved at: coursera_data\Business Analyst_microsoft powerpoint.csv
# -----------------------------------------------Scraping Complete Index (99/2666)-----------------------------------------------
# Business Analyst microsoft project
# Scraping URL: https://www.coursera.org/search?query=microsoft%20project%20microsoft%20project%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft project.csv saved at: coursera_data\Business Analyst_microsoft project.csv
# -----------------------------------------------Scraping Complete Index (100/2666)-----------------------------------------------
# Business Analyst microsoft sql
# Scraping URL: https://www.coursera.org/search?query=microsoft%20sql%20microsoft%20sql%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft sql.csv saved at: coursera_data\Business Analyst_microsoft sql.csv
# -----------------------------------------------Scraping Complete Index (101/2666)-----------------------------------------------
# Business Analyst microsoft sql server
# Scraping URL: https://www.coursera.org/search?query=microsoft%20sql%20server%20microsoft%20sql%20server%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft sql server.csv saved at: coursera_data\Business Analyst_microsoft sql server.csv
# -----------------------------------------------Scraping Complete Index (102/2666)-----------------------------------------------
# Business Analyst microsoft visio
# Scraping URL: https://www.coursera.org/search?query=microsoft%20visio%20microsoft%20visio%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft visio.csv saved at: coursera_data\Business Analyst_microsoft visio.csv
# -----------------------------------------------Scraping Complete Index (103/2666)-----------------------------------------------
# Business Analyst microsoft word
# Scraping URL: https://www.coursera.org/search?query=microsoft%20word%20microsoft%20word%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microsoft word.csv saved at: coursera_data\Business Analyst_microsoft word.csv
# -----------------------------------------------Scraping Complete Index (104/2666)-----------------------------------------------
# Business Analyst microstrategy
# Scraping URL: https://www.coursera.org/search?query=microstrategy%20microstrategy%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# microstrategy.csv saved at: coursera_data\Business Analyst_microstrategy.csv
# -----------------------------------------------Scraping Complete Index (105/2666)-----------------------------------------------
# Business Analyst mii - manufacturing intelligence and integration
# Scraping URL: https://www.coursera.org/search?query=mii%20-%20manufacturing%20intelligence%20and%20integration%20mii%20-%20manufacturing%20intelligence%20and%20integration%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# mii - manufacturing intelligence and integration.csv saved at: coursera_data\Business Analyst_mii - manufacturing intelligence and integration.csv
# -----------------------------------------------Scraping Complete Index (106/2666)-----------------------------------------------
# Business Analyst ms access
# Scraping URL: https://www.coursera.org/search?query=ms%20access%20ms%20access%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms access.csv saved at: coursera_data\Business Analyst_ms access.csv
# -----------------------------------------------Scraping Complete Index (107/2666)-----------------------------------------------
# Business Analyst ms excel
# Scraping URL: https://www.coursera.org/search?query=ms%20excel%20ms%20excel%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms excel.csv saved at: coursera_data\Business Analyst_ms excel.csv
# -----------------------------------------------Scraping Complete Index (108/2666)-----------------------------------------------
# Business Analyst ms office
# Scraping URL: https://www.coursera.org/search?query=ms%20office%20ms%20office%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms office.csv saved at: coursera_data\Business Analyst_ms office.csv
# -----------------------------------------------Scraping Complete Index (109/2666)-----------------------------------------------
# Business Analyst ms office suite
# Scraping URL: https://www.coursera.org/search?query=ms%20office%20suite%20ms%20office%20suite%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms office suite.csv saved at: coursera_data\Business Analyst_ms office suite.csv
# -----------------------------------------------Scraping Complete Index (110/2666)-----------------------------------------------
# Business Analyst ms powerpoint
# Scraping URL: https://www.coursera.org/search?query=ms%20powerpoint%20ms%20powerpoint%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms powerpoint.csv saved at: coursera_data\Business Analyst_ms powerpoint.csv
# -----------------------------------------------Scraping Complete Index (111/2666)-----------------------------------------------
# Business Analyst ms project
# Scraping URL: https://www.coursera.org/search?query=ms%20project%20ms%20project%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms project.csv saved at: coursera_data\Business Analyst_ms project.csv
# -----------------------------------------------Scraping Complete Index (112/2666)-----------------------------------------------
# Business Analyst ms sql server
# Scraping URL: https://www.coursera.org/search?query=ms%20sql%20server%20ms%20sql%20server%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms sql server.csv saved at: coursera_data\Business Analyst_ms sql server.csv
# -----------------------------------------------Scraping Complete Index (113/2666)-----------------------------------------------
# Business Analyst ms visio
# Scraping URL: https://www.coursera.org/search?query=ms%20visio%20ms%20visio%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms visio.csv saved at: coursera_data\Business Analyst_ms visio.csv
# -----------------------------------------------Scraping Complete Index (114/2666)-----------------------------------------------
# Business Analyst ms word
# Scraping URL: https://www.coursera.org/search?query=ms%20word%20ms%20word%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ms word.csv saved at: coursera_data\Business Analyst_ms word.csv
# -----------------------------------------------Scraping Complete Index (115/2666)-----------------------------------------------
# Business Analyst mysql
# Scraping URL: https://www.coursera.org/search?query=mysql%20mysql%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# mysql.csv saved at: coursera_data\Business Analyst_mysql.csv
# -----------------------------------------------Scraping Complete Index (116/2666)-----------------------------------------------
# Business Analyst node
# Scraping URL: https://www.coursera.org/search?query=node%20node%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# node.csv saved at: coursera_data\Business Analyst_node.csv
# -----------------------------------------------Scraping Complete Index (117/2666)-----------------------------------------------
# Business Analyst obiee
# Scraping URL: https://www.coursera.org/search?query=obiee%20obiee%20Business%20Analyst
# Scrolling and get num_course: 12-12-12-12-12-12-24
# Course divs found 24
# obiee.csv saved at: coursera_data\Business Analyst_obiee.csv
# -----------------------------------------------Scraping Complete Index (118/2666)-----------------------------------------------
# Business Analyst oracle
# Scraping URL: https://www.coursera.org/search?query=oracle%20oracle%20Business%20Analyst
# Scrolling and get num_course: 12-12-24
# Course divs found 24
# oracle.csv saved at: coursera_data\Business Analyst_oracle.csv
# -----------------------------------------------Scraping Complete Index (119/2666)-----------------------------------------------
# Business Analyst oracle database
# Scraping URL: https://www.coursera.org/search?query=oracle%20database%20oracle%20database%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# oracle database.csv saved at: coursera_data\Business Analyst_oracle database.csv
# -----------------------------------------------Scraping Complete Index (120/2666)-----------------------------------------------
# Business Analyst oracle ebs
# Scraping URL: https://www.coursera.org/search?query=oracle%20ebs%20oracle%20ebs%20Business%20Analyst
# Scrolling and get num_course: 12-24
# Course divs found 24
# ...
# -----------------------------------------------Scraping Complete Index (2626/2666)-----------------------------------------------
# Web Developer test-driven development
# Scraping URL: https://www.coursera.org/search?query=test-driven%20development%20test-driven%20development%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# test-driven development.csv saved at: coursera_data\Web Developer_test-driven development.csv
# -----------------------------------------------Scraping Complete Index (2627/2666)-----------------------------------------------
# Web Developer testing
# Scraping URL: https://www.coursera.org/search?query=testing%20testing%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# testing.csv saved at: coursera_data\Web Developer_testing.csv
# -----------------------------------------------Scraping Complete Index (2628/2666)-----------------------------------------------
# Web Developer tfs
# Scraping URL: https://www.coursera.org/search?query=tfs%20tfs%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# tfs.csv saved at: coursera_data\Web Developer_tfs.csv
# -----------------------------------------------Scraping Complete Index (2629/2666)-----------------------------------------------
# Web Developer tomcat
# Scraping URL: https://www.coursera.org/search?query=tomcat%20tomcat%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# tomcat.csv saved at: coursera_data\Web Developer_tomcat.csv
# -----------------------------------------------Scraping Complete Index (2630/2666)-----------------------------------------------
# Web Developer typescript
# Scraping URL: https://www.coursera.org/search?query=typescript%20typescript%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# typescript.csv saved at: coursera_data\Web Developer_typescript.csv
# -----------------------------------------------Scraping Complete Index (2631/2666)-----------------------------------------------
# Web Developer ui
# Scraping URL: https://www.coursera.org/search?query=ui%20ui%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# ui.csv saved at: coursera_data\Web Developer_ui.csv
# -----------------------------------------------Scraping Complete Index (2632/2666)-----------------------------------------------
# Web Developer ui design
# Scraping URL: https://www.coursera.org/search?query=ui%20design%20ui%20design%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# ui design.csv saved at: coursera_data\Web Developer_ui design.csv
# -----------------------------------------------Scraping Complete Index (2633/2666)-----------------------------------------------
# Web Developer unit testing
# Scraping URL: https://www.coursera.org/search?query=unit%20testing%20unit%20testing%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# unit testing.csv saved at: coursera_data\Web Developer_unit testing.csv
# -----------------------------------------------Scraping Complete Index (2634/2666)-----------------------------------------------
# Web Developer unix
# Scraping URL: https://www.coursera.org/search?query=unix%20unix%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# unix.csv saved at: coursera_data\Web Developer_unix.csv
# -----------------------------------------------Scraping Complete Index (2635/2666)-----------------------------------------------
# Web Developer unix shell scripting
# Scraping URL: https://www.coursera.org/search?query=unix%20shell%20scripting%20unix%20shell%20scripting%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# unix shell scripting.csv saved at: coursera_data\Web Developer_unix shell scripting.csv
# -----------------------------------------------Scraping Complete Index (2636/2666)-----------------------------------------------
# Web Developer unix/linux
# Scraping URL: https://www.coursera.org/search?query=unix/linux%20unix/linux%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# unix_linux.csv saved at: coursera_data\Web Developer_unix_linux.csv
# -----------------------------------------------Scraping Complete Index (2637/2666)-----------------------------------------------
# Web Developer user interface design
# Scraping URL: https://www.coursera.org/search?query=user%20interface%20design%20user%20interface%20design%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# user interface design.csv saved at: coursera_data\Web Developer_user interface design.csv
# -----------------------------------------------Scraping Complete Index (2638/2666)-----------------------------------------------
# Web Developer ux design
# Scraping URL: https://www.coursera.org/search?query=ux%20design%20ux%20design%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# ux design.csv saved at: coursera_data\Web Developer_ux design.csv
# -----------------------------------------------Scraping Complete Index (2639/2666)-----------------------------------------------
# Web Developer vb
# Scraping URL: https://www.coursera.org/search?query=vb%20vb%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# vb.csv saved at: coursera_data\Web Developer_vb.csv
# -----------------------------------------------Scraping Complete Index (2640/2666)-----------------------------------------------
# Web Developer vb.net
# Scraping URL: https://www.coursera.org/search?query=vb.net%20vb.net%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# vb.net.csv saved at: coursera_data\Web Developer_vb.net.csv
# -----------------------------------------------Scraping Complete Index (2641/2666)-----------------------------------------------
# Web Developer vba
# Scraping URL: https://www.coursera.org/search?query=vba%20vba%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# vba.csv saved at: coursera_data\Web Developer_vba.csv
# -----------------------------------------------Scraping Complete Index (2642/2666)-----------------------------------------------
# Web Developer version control
# Scraping URL: https://www.coursera.org/search?query=version%20control%20version%20control%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# version control.csv saved at: coursera_data\Web Developer_version control.csv
# -----------------------------------------------Scraping Complete Index (2643/2666)-----------------------------------------------
# Web Developer visual studio
# Scraping URL: https://www.coursera.org/search?query=visual%20studio%20visual%20studio%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# visual studio.csv saved at: coursera_data\Web Developer_visual studio.csv
# -----------------------------------------------Scraping Complete Index (2644/2666)-----------------------------------------------
# Web Developer visualforce
# Scraping URL: https://www.coursera.org/search?query=visualforce%20visualforce%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# visualforce.csv saved at: coursera_data\Web Developer_visualforce.csv
# -----------------------------------------------Scraping Complete Index (2645/2666)-----------------------------------------------
# Web Developer vue
# Scraping URL: https://www.coursera.org/search?query=vue%20vue%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# vue.csv saved at: coursera_data\Web Developer_vue.csv
# -----------------------------------------------Scraping Complete Index (2646/2666)-----------------------------------------------
# Web Developer wcf
# Scraping URL: https://www.coursera.org/search?query=wcf%20wcf%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# wcf.csv saved at: coursera_data\Web Developer_wcf.csv
# -----------------------------------------------Scraping Complete Index (2647/2666)-----------------------------------------------
# Web Developer web api
# Scraping URL: https://www.coursera.org/search?query=web%20api%20web%20api%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# web api.csv saved at: coursera_data\Web Developer_web api.csv
# -----------------------------------------------Scraping Complete Index (2648/2666)-----------------------------------------------
# Web Developer web applications
# Scraping URL: https://www.coursera.org/search?query=web%20applications%20web%20applications%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# web applications.csv saved at: coursera_data\Web Developer_web applications.csv
# -----------------------------------------------Scraping Complete Index (2649/2666)-----------------------------------------------
# Web Developer web development
# Scraping URL: https://www.coursera.org/search?query=web%20development%20web%20development%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# web development.csv saved at: coursera_data\Web Developer_web development.csv
# -----------------------------------------------Scraping Complete Index (2650/2666)-----------------------------------------------
# Web Developer web forms
# Scraping URL: https://www.coursera.org/search?query=web%20forms%20web%20forms%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# web forms.csv saved at: coursera_data\Web Developer_web forms.csv
# -----------------------------------------------Scraping Complete Index (2651/2666)-----------------------------------------------
# Web Developer web service
# Scraping URL: https://www.coursera.org/search?query=web%20service%20web%20service%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# web service.csv saved at: coursera_data\Web Developer_web service.csv
# -----------------------------------------------Scraping Complete Index (2652/2666)-----------------------------------------------
# Web Developer web services
# Scraping URL: https://www.coursera.org/search?query=web%20services%20web%20services%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# web services.csv saved at: coursera_data\Web Developer_web services.csv
# -----------------------------------------------Scraping Complete Index (2653/2666)-----------------------------------------------
# Web Developer webapi
# Scraping URL: https://www.coursera.org/search?query=webapi%20webapi%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# webapi.csv saved at: coursera_data\Web Developer_webapi.csv
# -----------------------------------------------Scraping Complete Index (2654/2666)-----------------------------------------------
# Web Developer webpack
# Scraping URL: https://www.coursera.org/search?query=webpack%20webpack%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# webpack.csv saved at: coursera_data\Web Developer_webpack.csv
# -----------------------------------------------Scraping Complete Index (2655/2666)-----------------------------------------------
# Web Developer websocket
# Scraping URL: https://www.coursera.org/search?query=websocket%20websocket%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# websocket.csv saved at: coursera_data\Web Developer_websocket.csv
# -----------------------------------------------Scraping Complete Index (2656/2666)-----------------------------------------------
# Web Developer window
# Scraping URL: https://www.coursera.org/search?query=window%20window%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# window.csv saved at: coursera_data\Web Developer_window.csv
# -----------------------------------------------Scraping Complete Index (2657/2666)-----------------------------------------------
# Web Developer winform
# Scraping URL: https://www.coursera.org/search?query=winform%20winform%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# winform.csv saved at: coursera_data\Web Developer_winform.csv
# -----------------------------------------------Scraping Complete Index (2658/2666)-----------------------------------------------
# Web Developer wireframes
# Scraping URL: https://www.coursera.org/search?query=wireframes%20wireframes%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# wireframes.csv saved at: coursera_data\Web Developer_wireframes.csv
# -----------------------------------------------Scraping Complete Index (2659/2666)-----------------------------------------------
# Web Developer wordpress
# Scraping URL: https://www.coursera.org/search?query=wordpress%20wordpress%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# wordpress.csv saved at: coursera_data\Web Developer_wordpress.csv
# -----------------------------------------------Scraping Complete Index (2660/2666)-----------------------------------------------
# Web Developer wpf
# Scraping URL: https://www.coursera.org/search?query=wpf%20wpf%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# wpf.csv saved at: coursera_data\Web Developer_wpf.csv
# -----------------------------------------------Scraping Complete Index (2661/2666)-----------------------------------------------
# Web Developer xamarin
# Scraping URL: https://www.coursera.org/search?query=xamarin%20xamarin%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# xamarin.csv saved at: coursera_data\Web Developer_xamarin.csv
# -----------------------------------------------Scraping Complete Index (2662/2666)-----------------------------------------------
# Web Developer xcode
# Scraping URL: https://www.coursera.org/search?query=xcode%20xcode%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# xcode.csv saved at: coursera_data\Web Developer_xcode.csv
# -----------------------------------------------Scraping Complete Index (2663/2666)-----------------------------------------------
# Web Developer xhtml
# Scraping URL: https://www.coursera.org/search?query=xhtml%20xhtml%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# xhtml.csv saved at: coursera_data\Web Developer_xhtml.csv
# -----------------------------------------------Scraping Complete Index (2664/2666)-----------------------------------------------
# Web Developer xml
# Scraping URL: https://www.coursera.org/search?query=xml%20xml%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# xml.csv saved at: coursera_data\Web Developer_xml.csv
# -----------------------------------------------Scraping Complete Index (2665/2666)-----------------------------------------------
# Web Developer xom
# Scraping URL: https://www.coursera.org/search?query=xom%20xom%20Web%20Developer
# Scrolling and get num_course: 12-12-12-12-12-12-12-12-12-12-12
# Course divs found 12
# xom.csv saved at: coursera_data\Web Developer_xom.csv
# -----------------------------------------------Scraping Complete Index (2666/2666)-----------------------------------------------
