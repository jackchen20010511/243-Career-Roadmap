# %%
import os
import time
import urllib.parse
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait
import re

# Setup Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--lang=en-US")  # Force browser to load English
options.add_argument("--headless")  # Run in headless mode (no GUI)
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920,1080")
options.add_argument("--log-level=3")  # Suppress logs

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# --------------------------------------------------------------------------------------------------------------------------
# Search skills: what skills do you want to get course data on
# --------------------------------------------------------------------------------------------------------------------------
# Specify the path to the file containing the extracted skills
file_path = './all_skills.txt'
data_folder = "youtube_data"
os.makedirs(data_folder, exist_ok=True)  # Ensure folder exists


# Open the file and read its contents
with open(file_path, 'r', encoding='utf-8') as file:
    skills = file.readlines()  # Read each line as an individual skill
tech_skills = [skill.strip() for skill in skills]

latest_skill_index = 4603

# List of URLs to scrape
url_list = ["https://www.youtube.com/results?search_query="+skill.replace(" ","+")+"+Course"\
            for skill in tech_skills[latest_skill_index:]]  # Add more URLs as needed

# Function to scroll down to load dynamic content
def scroll_page(n,target_tag, target_class):
    """scroll page utill there are n course cards or no new contents are loaded"""
    num_video = len(driver.find_elements(By.CSS_SELECTOR, target_tag+'.'+target_class.replace(" ", ".")))
    no_new_scroll = 0
    print(f"Scrolling and get num_course: {num_video}",end="")
    while num_video < n and no_new_scroll < 10:  # Adjust range as needed
        driver.execute_script("window.scrollBy(0, 1500);")
        time.sleep(1.5)# Wait for content to load
        new_num_video = len(driver.find_elements(By.CSS_SELECTOR, target_tag+'.'+target_class.replace(" ", ".")))
        print(f"-{new_num_video}",end="")
        if new_num_video > num_video:
            no_new_scroll = 0
            num_video = new_num_video
        else:
            no_new_scroll += 1
    print('')
    
data = []

for idx, url in enumerate(url_list):
    try:
        print(f"Scraping URL: {url}")
        driver.get(url)
        while not driver.page_source:
            time.sleep(3)# Wait for initial load
        target_tag = 'ytd-video-renderer'
        target_class = "style-scope ytd-item-section-renderer"
        # ------------------------------------------------------------------------------------------------------------------
        # Scroll page; change number of courses you want to scroll and scrape for each skill
        # ------------------------------------------------------------------------------------------------------------------
        scroll_page(10,target_tag,target_class)
    except Exception as e:
        print(f"Failed to scrape {url}: {e}")

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find all product containers
    video_divs = soup.find_all('ytd-video-renderer', class_= "style-scope ytd-item-section-renderer")
    num_videos = len(video_divs)
    print(f"Video divs found {num_videos}")

    def thumbnails_loaded(driver):
        driver.execute_script("window.scrollBy(0, 1500);")
        video_divs = driver.find_elements(By.CSS_SELECTOR, "ytd-video-renderer.style-scope.ytd-item-section-renderer")  # Refresh the list in case of updates
        count = 0
        for video in video_divs[:num_videos]:
            if video:
                thumbnail = video.find_elements(By.CSS_SELECTOR, "a#thumbnail.yt-simple-endpoint.inline-block.style-scope.ytd-thumbnail img.yt-core-image--loaded")
                if thumbnail:
                    count += 1
        return count >= num_videos
    try:
        WebDriverWait(driver, 5).until(thumbnails_loaded)
    except:
        None
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    video_divs = soup.find_all('ytd-video-renderer', class_= "style-scope ytd-item-section-renderer")[:num_videos]

    # Get skill name
    skill_name = tech_skills[latest_skill_index + idx]
    
    # Extract information
    video = []
    for div in video_divs:
        if div:
            # Extract video link
            video_tag = div.find("a", attrs={"class": "yt-simple-endpoint inline-block style-scope ytd-thumbnail", "id": "thumbnail"})
            video_link = "https://youtube.com"+video_tag.get("href") if video_tag else None
            thumbnail_tag = video_tag.find("img") if video_tag else None
            thumbnail_link = thumbnail_tag.get("src") if thumbnail_tag else None

            # Extract video title
            title_div =div.find("a", attrs={"class": "yt-simple-endpoint style-scope ytd-video-renderer", "id": "video-title"})
            title_tag = title_div.find("yt-formatted-string", class_="style-scope ytd-video-renderer") if title_div else None
            title = title_tag.text.strip() if title_tag else None

            # Extract num_views and video age
            num_views_div = div.find("div", attrs={"class": "style-scope ytd-video-meta-block", "id": "metadata-line"})
            metadata_items = [span.text for span in num_views_div.find_all("span")] if num_views_div else None
            if metadata_items and len(metadata_items) >= 2:
                num_views, age = metadata_items[0], metadata_items[1]
                if not age.endswith("ago"):
                    num_views, age = age, num_views  # Swap values if needed
            elif metadata_items and len(metadata_items) == 1:
                if "ago" in metadata_items[0]:
                    num_views, age = None, metadata_items[0]  # It's age, set views to None
                else:
                    num_views, age = metadata_items[0], None  # It's views, set age to None
            else:
                num_views, age = None, None

            # Extract channel name
            channel_tag = div.find("yt-formatted-string", attrs={"class": "style-scope ytd-channel-name", "id": "text"})
            channel = channel_tag.text.strip() if channel_tag else None

            # Extract video snippet
            snippet_div = div.find("yt-formatted-string", class_="metadata-snippet-text style-scope ytd-video-renderer")
            snippet_tag = snippet_div.find_all("span") if snippet_div else None
            snippet = " ".join(span.text.strip() for span in snippet_tag) if snippet_tag else None
            
            # Extract video duration
            duration_tag = div.find("span", attrs={"class": "style-scope ytd-thumbnail-overlay-time-status-renderer", "id": "text"})
            duration = duration_tag.text.strip() if duration_tag else None
            
            # Extract course series
            series_div = div.find("div", attrs={"class": "style-scope ytd-expandable-metadata-renderer", "id": "header"})
            chapter_div = series_div.find("yt-formatted-string",\
                          attrs={"class": "style-scope ytd-expandable-metadata-renderer", "id": "prominent-label-text"})\
                          if series_div else None
            chapter_tag = chapter_div.find("span") if chapter_div else None
            chapter = chapter_tag.text.strip() if chapter_tag else None
            series_div2 = series_div.find("div", attrs={"class": "style-scope ytd-expandable-metadata-renderer", "id": "collapsed-title"})\
                          if series_div else None
            text_tag = series_div2.find("yt-formatted-string") if series_div2 else None
            text = text_tag.text if text_tag else None
            topics = text.split(" | ") if text else None
            series = [re.sub(r"^\d+\.", "", topic).strip() for topic in topics] if topics else None

            
            # Append extracted data
            video.append({
                'skill': skill_name,
                'thumbnail_link': thumbnail_link,
                'video_link': video_link,
                'title': title,
                'num_views': num_views,
                'age': age,
                'channel': channel,
                'snippet': snippet,
                'duration': duration,
                'chapter': chapter,
                'series': series
            })
    df = pd.DataFrame(video)
    skillname = skill_name.replace("/", "_").replace("*", "_")
    csv_path = os.path.join(data_folder, f"{skillname}.csv")
    df.to_csv(csv_path, index=False)
    print(f"{skillname}.csv saved at: {csv_path}")
    print(f"-----------------------------------------------Scraping Complete ({latest_skill_index + idx+1}/{len(tech_skills)})-----------------------------------------------")
            
# Close the driver after scraping
driver.quit()
# Out:
# Scraping URL: https://www.youtube.com/results?search_query=Python+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Python.csv saved at: youtube_data\Python.csv
# -----------------------------------------------Scraping Complete (1/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Java+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Java.csv saved at: youtube_data\Java.csv
# -----------------------------------------------Scraping Complete (2/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Sql+Course
# Scrolling and get num_course: 14
# Video divs found 14
# Sql.csv saved at: youtube_data\Sql.csv
# -----------------------------------------------Scraping Complete (3/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Aws+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Aws.csv saved at: youtube_data\Aws.csv
# -----------------------------------------------Scraping Complete (4/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Machine+Learning+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Machine Learning.csv saved at: youtube_data\Machine Learning.csv
# -----------------------------------------------Scraping Complete (5/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=JS+Course
# Scrolling and get num_course: 15
# Video divs found 15
# JS.csv saved at: youtube_data\JS.csv
# -----------------------------------------------Scraping Complete (6/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=C+++Course
# Scrolling and get num_course: 12
# Video divs found 12
# C++.csv saved at: youtube_data\C++.csv
# -----------------------------------------------Scraping Complete (7/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Linux+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Linux.csv saved at: youtube_data\Linux.csv
# -----------------------------------------------Scraping Complete (8/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Kubernetes+Course
# Scrolling and get num_course: 12
# Video divs found 15
# Kubernetes.csv saved at: youtube_data\Kubernetes.csv
# -----------------------------------------------Scraping Complete (9/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Git+Course
# Scrolling and get num_course: 19
# Video divs found 19
# Git.csv saved at: youtube_data\Git.csv
# -----------------------------------------------Scraping Complete (10/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=R+Course
# Scrolling and get num_course: 9-9-9-9-9-9-9-28
# Video divs found 28
# R.csv saved at: youtube_data\R.csv
# -----------------------------------------------Scraping Complete (11/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Docker+Course
# Scrolling and get num_course: 15
# Video divs found 18
# Docker.csv saved at: youtube_data\Docker.csv
# -----------------------------------------------Scraping Complete (12/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=React+Course
# Scrolling and get num_course: 14
# Video divs found 15
# React.csv saved at: youtube_data\React.csv
# -----------------------------------------------Scraping Complete (13/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=C#+Course
# Scrolling and get num_course: 19
# Video divs found 20
# C#.csv saved at: youtube_data\C#.csv
# -----------------------------------------------Scraping Complete (14/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Spark+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Spark.csv saved at: youtube_data\Spark.csv
# -----------------------------------------------Scraping Complete (15/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Node+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Node.csv saved at: youtube_data\Node.csv
# -----------------------------------------------Scraping Complete (16/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=TensorFlow+Course
# Scrolling and get num_course: 14
# Video divs found 14
# TensorFlow.csv saved at: youtube_data\TensorFlow.csv
# -----------------------------------------------Scraping Complete (17/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=TerraForm+Course
# Scrolling and get num_course: 10
# Video divs found 11
# TerraForm.csv saved at: youtube_data\TerraForm.csv
# -----------------------------------------------Scraping Complete (18/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Azure+Course
# Scrolling and get num_course: 8-14
# Video divs found 14
# Azure.csv saved at: youtube_data\Azure.csv
# -----------------------------------------------Scraping Complete (19/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=C+Course
# Scrolling and get num_course: 7-12
# Video divs found 12
# C.csv saved at: youtube_data\C.csv
# -----------------------------------------------Scraping Complete (20/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Go+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Go.csv saved at: youtube_data\Go.csv
# -----------------------------------------------Scraping Complete (21/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=CI+Course
# Scrolling and get num_course: 18
# Video divs found 18
# CI.csv saved at: youtube_data\CI.csv
# -----------------------------------------------Scraping Complete (22/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Communication+Skills+Course
# Scrolling and get num_course: 16
# Video divs found 17
# Communication Skills.csv saved at: youtube_data\Communication Skills.csv
# -----------------------------------------------Scraping Complete (23/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=PyTorch+Course
# Scrolling and get num_course: 14
# Video divs found 14
# PyTorch.csv saved at: youtube_data\PyTorch.csv
# -----------------------------------------------Scraping Complete (24/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=GCP+Course
# Scrolling and get num_course: 11
# Video divs found 11
# GCP.csv saved at: youtube_data\GCP.csv
# -----------------------------------------------Scraping Complete (25/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Scala+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Scala.csv saved at: youtube_data\Scala.csv
# -----------------------------------------------Scraping Complete (26/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=HTML+Course
# Scrolling and get num_course: 16
# Video divs found 16
# HTML.csv saved at: youtube_data\HTML.csv
# -----------------------------------------------Scraping Complete (27/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Agile+Course
# Scrolling and get num_course: 16
# Video divs found 18
# Agile.csv saved at: youtube_data\Agile.csv
# -----------------------------------------------Scraping Complete (28/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Angular+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Angular.csv saved at: youtube_data\Angular.csv
# -----------------------------------------------Scraping Complete (29/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Ansible+Course
# Scrolling and get num_course: 9-9-9-9-9-9-20
# Video divs found 20
# Ansible.csv saved at: youtube_data\Ansible.csv
# -----------------------------------------------Scraping Complete (30/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=css+Course
# Scrolling and get num_course: 15
# Video divs found 15
# css.csv saved at: youtube_data\css.csv
# -----------------------------------------------Scraping Complete (31/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Typescript+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Typescript.csv saved at: youtube_data\Typescript.csv
# -----------------------------------------------Scraping Complete (32/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Jenkin+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Jenkin.csv saved at: youtube_data\Jenkin.csv
# -----------------------------------------------Scraping Complete (33/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Deep+Learning+Course
# Scrolling and get num_course: 10
# Video divs found 10
# Deep Learning.csv saved at: youtube_data\Deep Learning.csv
# -----------------------------------------------Scraping Complete (34/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Problem+Solving+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Problem Solving.csv saved at: youtube_data\Problem Solving.csv
# -----------------------------------------------Scraping Complete (35/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Ruby+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Ruby.csv saved at: youtube_data\Ruby.csv
# -----------------------------------------------Scraping Complete (36/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Hadoop+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Hadoop.csv saved at: youtube_data\Hadoop.csv
# -----------------------------------------------Scraping Complete (37/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=NLP+Course
# Scrolling and get num_course: 6-6-6-6-6-22
# Video divs found 22
# NLP.csv saved at: youtube_data\NLP.csv
# -----------------------------------------------Scraping Complete (38/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=CD+Course
# Scrolling and get num_course: 17
# Video divs found 17
# CD.csv saved at: youtube_data\CD.csv
# -----------------------------------------------Scraping Complete (39/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Communication+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Communication.csv saved at: youtube_data\Communication.csv
# -----------------------------------------------Scraping Complete (40/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=DevOPS+Course
# Scrolling and get num_course: 10
# Video divs found 15
# DevOPS.csv saved at: youtube_data\DevOPS.csv
# -----------------------------------------------Scraping Complete (41/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Tableau+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Tableau.csv saved at: youtube_data\Tableau.csv
# -----------------------------------------------Scraping Complete (42/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Kafka+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Kafka.csv saved at: youtube_data\Kafka.csv
# -----------------------------------------------Scraping Complete (43/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Statistics+Course
# Scrolling and get num_course: 6-6-6-6-6-6-25
# Video divs found 25
# Statistics.csv saved at: youtube_data\Statistics.csv
# -----------------------------------------------Scraping Complete (44/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Mysql+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Mysql.csv saved at: youtube_data\Mysql.csv
# -----------------------------------------------Scraping Complete (45/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Bash+Course
# Scrolling and get num_course: 9-9-9-9-9-9-9-23
# Video divs found 23
# Bash.csv saved at: youtube_data\Bash.csv
# -----------------------------------------------Scraping Complete (46/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Net+Course
# Scrolling and get num_course: 9-9-9-9-9-9-28
# Video divs found 28
# Net.csv saved at: youtube_data\Net.csv
# -----------------------------------------------Scraping Complete (47/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Data+Science+Course
# Scrolling and get num_course: 19
# Video divs found 19
# Data Science.csv saved at: youtube_data\Data Science.csv
# -----------------------------------------------Scraping Complete (48/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=PostgreSql+Course
# Scrolling and get num_course: 10
# Video divs found 10
# PostgreSql.csv saved at: youtube_data\PostgreSql.csv
# -----------------------------------------------Scraping Complete (49/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Scikit+Learn+Course
# Scrolling and get num_course: 10
# Video divs found 10
# Scikit Learn.csv saved at: youtube_data\Scikit Learn.csv
# -----------------------------------------------Scraping Complete (50/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=NoSQL+Course
# Scrolling and get num_course: 17
# Video divs found 17
# NoSQL.csv saved at: youtube_data\NoSQL.csv
# -----------------------------------------------Scraping Complete (51/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Unix+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Unix.csv saved at: youtube_data\Unix.csv
# -----------------------------------------------Scraping Complete (52/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Pandas+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Pandas.csv saved at: youtube_data\Pandas.csv
# -----------------------------------------------Scraping Complete (53/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Chef+Course
# Scrolling and get num_course: 17
# Video divs found 17
# Chef.csv saved at: youtube_data\Chef.csv
# -----------------------------------------------Scraping Complete (54/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Puppet+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Puppet.csv saved at: youtube_data\Puppet.csv
# -----------------------------------------------Scraping Complete (55/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Postgres+Course
# Scrolling and get num_course: 10
# Video divs found 10
# Postgres.csv saved at: youtube_data\Postgres.csv
# -----------------------------------------------Scraping Complete (56/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=GoLang+Course
# Scrolling and get num_course: 16
# Video divs found 16
# GoLang.csv saved at: youtube_data\GoLang.csv
# -----------------------------------------------Scraping Complete (57/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Keras+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Keras.csv saved at: youtube_data\Keras.csv
# -----------------------------------------------Scraping Complete (58/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Data+Visualization+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Data Visualization.csv saved at: youtube_data\Data Visualization.csv
# -----------------------------------------------Scraping Complete (59/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=PHP+Course
# Scrolling and get num_course: 11
# Video divs found 11
# PHP.csv saved at: youtube_data\PHP.csv
# -----------------------------------------------Scraping Complete (60/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Collaboration+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Collaboration.csv saved at: youtube_data\Collaboration.csv
# -----------------------------------------------Scraping Complete (61/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Data+Structure+Course
# Scrolling and get num_course: 9-9-9-9-9-9-27
# Video divs found 27
# Data Structure.csv saved at: youtube_data\Data Structure.csv
# -----------------------------------------------Scraping Complete (62/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=GitHub+Course
# Scrolling and get num_course: 19
# Video divs found 19
# GitHub.csv saved at: youtube_data\GitHub.csv
# -----------------------------------------------Scraping Complete (63/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Rest+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Rest.csv saved at: youtube_data\Rest.csv
# -----------------------------------------------Scraping Complete (64/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Hive+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Hive.csv saved at: youtube_data\Hive.csv
# -----------------------------------------------Scraping Complete (65/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Jira+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Jira.csv saved at: youtube_data\Jira.csv
# -----------------------------------------------Scraping Complete (66/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Algorithm+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Algorithm.csv saved at: youtube_data\Algorithm.csv
# -----------------------------------------------Scraping Complete (67/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=NumPy+Course
# Scrolling and get num_course: 11
# Video divs found 13
# NumPy.csv saved at: youtube_data\NumPy.csv
# -----------------------------------------------Scraping Complete (68/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Rest+API+Course
# Scrolling and get num_course: 11
# Video divs found 16
# Rest API.csv saved at: youtube_data\Rest API.csv
# -----------------------------------------------Scraping Complete (69/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Distributed+System+Course
# Scrolling and get num_course: 10
# Video divs found 10
# Distributed System.csv saved at: youtube_data\Distributed System.csv
# -----------------------------------------------Scraping Complete (70/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Prometheus+Course
# Scrolling and get num_course: 15
# Video divs found 16
# Prometheus.csv saved at: youtube_data\Prometheus.csv
# -----------------------------------------------Scraping Complete (71/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=GraphQL+Course
# Scrolling and get num_course: 14
# Video divs found 14
# GraphQL.csv saved at: youtube_data\GraphQL.csv
# -----------------------------------------------Scraping Complete (72/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=PowerShell+Course
# Scrolling and get num_course: 9-9-9-9-9-9-9-24
# Video divs found 24
# PowerShell.csv saved at: youtube_data\PowerShell.csv
# -----------------------------------------------Scraping Complete (73/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Elasticsearch+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Elasticsearch.csv saved at: youtube_data\Elasticsearch.csv
# -----------------------------------------------Scraping Complete (74/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Redis+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Redis.csv saved at: youtube_data\Redis.csv
# -----------------------------------------------Scraping Complete (75/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Json+Course
# Scrolling and get num_course: 16
# Video divs found 17
# Json.csv saved at: youtube_data\Json.csv
# -----------------------------------------------Scraping Complete (76/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Analytical+Skills+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Analytical Skills.csv saved at: youtube_data\Analytical Skills.csv
# -----------------------------------------------Scraping Complete (77/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Grafana+Course
# Scrolling and get num_course: 8-14
# Video divs found 14
# Grafana.csv saved at: youtube_data\Grafana.csv
# -----------------------------------------------Scraping Complete (78/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=MongoDB+Course
# Scrolling and get num_course: 15
# Video divs found 15
# MongoDB.csv saved at: youtube_data\MongoDB.csv
# -----------------------------------------------Scraping Complete (79/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Airflow+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Airflow.csv saved at: youtube_data\Airflow.csv
# -----------------------------------------------Scraping Complete (80/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Perl+Course
# Scrolling and get num_course: 12
# Video divs found 14
# Perl.csv saved at: youtube_data\Perl.csv
# -----------------------------------------------Scraping Complete (81/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=SAS+Course
# Scrolling and get num_course: 10
# Video divs found 10
# SAS.csv saved at: youtube_data\SAS.csv
# -----------------------------------------------Scraping Complete (82/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Vue+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Vue.csv saved at: youtube_data\Vue.csv
# -----------------------------------------------Scraping Complete (83/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=MatLab+Course
# Scrolling and get num_course: 7-7-7-7-7-7-7-20
# Video divs found 20
# MatLab.csv saved at: youtube_data\MatLab.csv
# -----------------------------------------------Scraping Complete (84/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Interpersonal+Skills+Course
# Scrolling and get num_course: 17
# Video divs found 17
# Interpersonal Skills.csv saved at: youtube_data\Interpersonal Skills.csv
# -----------------------------------------------Scraping Complete (85/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Restful+API+Course
# Scrolling and get num_course: 14
# Video divs found 14
# Restful API.csv saved at: youtube_data\Restful API.csv
# -----------------------------------------------Scraping Complete (86/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Computer+Vision+Course
# Scrolling and get num_course: 7-7-7-7-7-7-21
# Video divs found 21
# Computer Vision.csv saved at: youtube_data\Computer Vision.csv
# -----------------------------------------------Scraping Complete (87/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Data+Mining+Course
# Scrolling and get num_course: 7-7-7-7-7-7-21
# Video divs found 21
# Data Mining.csv saved at: youtube_data\Data Mining.csv
# -----------------------------------------------Scraping Complete (88/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=HTML5+Course
# Scrolling and get num_course: 16
# Video divs found 16
# HTML5.csv saved at: youtube_data\HTML5.csv
# -----------------------------------------------Scraping Complete (89/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=ETL+Course
# Scrolling and get num_course: 15
# Video divs found 15
# ETL.csv saved at: youtube_data\ETL.csv
# -----------------------------------------------Scraping Complete (90/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Oracle+Course
# Scrolling and get num_course: 10
# Video divs found 10
# Oracle.csv saved at: youtube_data\Oracle.csv
# -----------------------------------------------Scraping Complete (91/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Relational+Database+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Relational Database.csv saved at: youtube_data\Relational Database.csv
# -----------------------------------------------Scraping Complete (92/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Splunk+Course
# Scrolling and get num_course: 9-9-9-9-9-9-23
# Video divs found 23
# Splunk.csv saved at: youtube_data\Splunk.csv
# -----------------------------------------------Scraping Complete (93/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Redux+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Redux.csv saved at: youtube_data\Redux.csv
# -----------------------------------------------Scraping Complete (94/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Spring+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Spring.csv saved at: youtube_data\Spring.csv
# -----------------------------------------------Scraping Complete (95/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Continuous+Integration+Course
# Scrolling and get num_course: 13
# Video divs found 20
# Continuous Integration.csv saved at: youtube_data\Continuous Integration.csv
# -----------------------------------------------Scraping Complete (96/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=MicroServices+Course
# Scrolling and get num_course: 8-8-8-8-8-8-23
# Video divs found 25
# MicroServices.csv saved at: youtube_data\MicroServices.csv
# -----------------------------------------------Scraping Complete (97/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Ruby+on+Rails+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Ruby on Rails.csv saved at: youtube_data\Ruby on Rails.csv
# -----------------------------------------------Scraping Complete (98/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Infrastructure+As+Code+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Infrastructure As Code.csv saved at: youtube_data\Infrastructure As Code.csv
# -----------------------------------------------Scraping Complete (99/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=SQL+Server+Course
# Scrolling and get num_course: 14
# Video divs found 14
# SQL Server.csv saved at: youtube_data\SQL Server.csv
# -----------------------------------------------Scraping Complete (100/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=XML+Course
# Scrolling and get num_course: 14
# Video divs found 14
# XML.csv saved at: youtube_data\XML.csv
# -----------------------------------------------Scraping Complete (101/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Attention+to+Detail+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Attention to Detail.csv saved at: youtube_data\Attention to Detail.csv
# -----------------------------------------------Scraping Complete (102/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Data+Analysis+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Data Analysis.csv saved at: youtube_data\Data Analysis.csv
# -----------------------------------------------Scraping Complete (103/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Big+Data+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Big Data.csv saved at: youtube_data\Big Data.csv
# -----------------------------------------------Scraping Complete (104/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Web+Services+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Web Services.csv saved at: youtube_data\Web Services.csv
# -----------------------------------------------Scraping Complete (105/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Automation+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Automation.csv saved at: youtube_data\Automation.csv
# -----------------------------------------------Scraping Complete (106/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Data+Modeling+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Data Modeling.csv saved at: youtube_data\Data Modeling.csv
# -----------------------------------------------Scraping Complete (107/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=TCP+Course
# Scrolling and get num_course: 17
# Video divs found 17
# TCP.csv saved at: youtube_data\TCP.csv
# -----------------------------------------------Scraping Complete (108/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Teamwork+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Teamwork.csv saved at: youtube_data\Teamwork.csv
# -----------------------------------------------Scraping Complete (109/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Networking+Course
# Scrolling and get num_course: 9-9-9-9-9-9-27
# Video divs found 27
# Networking.csv saved at: youtube_data\Networking.csv
# -----------------------------------------------Scraping Complete (110/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Swift+Course
# Scrolling and get num_course: 14
# Video divs found 14
# Swift.csv saved at: youtube_data\Swift.csv
# -----------------------------------------------Scraping Complete (111/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=AI+Course
# Scrolling and get num_course: 17
# Video divs found 17
# AI.csv saved at: youtube_data\AI.csv
# -----------------------------------------------Scraping Complete (112/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Spring+Boot+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Spring Boot.csv saved at: youtube_data\Spring Boot.csv
# -----------------------------------------------Scraping Complete (113/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Statistical+Modeling+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Statistical Modeling.csv saved at: youtube_data\Statistical Modeling.csv
# -----------------------------------------------Scraping Complete (114/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Django+Course
# Scrolling and get num_course: 11
# Video divs found 11
# Django.csv saved at: youtube_data\Django.csv
# -----------------------------------------------Scraping Complete (115/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=PySpark+Course
# Scrolling and get num_course: 10
# Video divs found 10
# PySpark.csv saved at: youtube_data\PySpark.csv
# -----------------------------------------------Scraping Complete (116/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Shell+Scripting+Course
# Scrolling and get num_course: 7-7-7-7-7-7-7-24
# Video divs found 24
# Shell Scripting.csv saved at: youtube_data\Shell Scripting.csv
# -----------------------------------------------Scraping Complete (117/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Cassandra+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Cassandra.csv saved at: youtube_data\Cassandra.csv
# -----------------------------------------------Scraping Complete (118/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Machine+Learning+Algorithms+Course
# Scrolling and get num_course: 17
# Video divs found 17
# Machine Learning Algorithms.csv saved at: youtube_data\Machine Learning Algorithms.csv
# -----------------------------------------------Scraping Complete (119/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=API+Course
# Scrolling and get num_course: 13
# Video divs found 13
# API.csv saved at: youtube_data\API.csv
# -----------------------------------------------Scraping Complete (120/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Artificial+Intelligence+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Artificial Intelligence.csv saved at: youtube_data\Artificial Intelligence.csv
# -----------------------------------------------Scraping Complete (121/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Statistical+Analysis+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Statistical Analysis.csv saved at: youtube_data\Statistical Analysis.csv
# -----------------------------------------------Scraping Complete (122/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Kotlin+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Kotlin.csv saved at: youtube_data\Kotlin.csv
# -----------------------------------------------Scraping Complete (123/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Windows+Course
# Scrolling and get num_course: 16
# Video divs found 17
# Windows.csv saved at: youtube_data\Windows.csv
# -----------------------------------------------Scraping Complete (124/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Snowflake+Course
# Scrolling and get num_course: 12
# Video divs found 12
# Snowflake.csv saved at: youtube_data\Snowflake.csv
# -----------------------------------------------Scraping Complete (125/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Jquery+Course
# Scrolling and get num_course: 9-9-9-9-9-9-9-22
# Video divs found 22
# Jquery.csv saved at: youtube_data\Jquery.csv
# -----------------------------------------------Scraping Complete (126/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Verbal+and+Written+Communication+Course
# Scrolling and get num_course: 19
# Video divs found 19
# Verbal and Written Communication.csv saved at: youtube_data\Verbal and Written Communication.csv
# -----------------------------------------------Scraping Complete (127/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Selenium+Course
# Scrolling and get num_course: 9-9-9-9-9-9-9-26
# Video divs found 26
# Selenium.csv saved at: youtube_data\Selenium.csv
# -----------------------------------------------Scraping Complete (128/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Data+Engineering+Course
# Scrolling and get num_course: 9-9-9-9-9-9-29
# Video divs found 29
# Data Engineering.csv saved at: youtube_data\Data Engineering.csv
# -----------------------------------------------Scraping Complete (129/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Leadership+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Leadership.csv saved at: youtube_data\Leadership.csv
# -----------------------------------------------Scraping Complete (130/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Organizational+Skills+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Organizational Skills.csv saved at: youtube_data\Organizational Skills.csv
# -----------------------------------------------Scraping Complete (131/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Maven+Course
# Scrolling and get num_course: 17
# Video divs found 17
# Maven.csv saved at: youtube_data\Maven.csv
# -----------------------------------------------Scraping Complete (132/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=CD+Pipeline+Course
# Scrolling and get num_course: 20
# Video divs found 20
# CD Pipeline.csv saved at: youtube_data\CD Pipeline.csv
# -----------------------------------------------Scraping Complete (133/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Software+Development+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Software Development.csv saved at: youtube_data\Software Development.csv
# -----------------------------------------------Scraping Complete (134/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Power+BI+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Power BI.csv saved at: youtube_data\Power BI.csv
# -----------------------------------------------Scraping Complete (135/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Hibernate+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Hibernate.csv saved at: youtube_data\Hibernate.csv
# -----------------------------------------------Scraping Complete (136/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=IP+Course
# Scrolling and get num_course: 18
# Video divs found 18
# IP.csv saved at: youtube_data\IP.csv
# -----------------------------------------------Scraping Complete (137/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=A+Course
# Scrolling and get num_course: 14
# Video divs found 19
# A.csv saved at: youtube_data\A.csv
# -----------------------------------------------Scraping Complete (138/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Team+Player+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Team Player.csv saved at: youtube_data\Team Player.csv
# -----------------------------------------------Scraping Complete (139/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Configuration+Management+Course
# Scrolling and get num_course: 19
# Video divs found 19
# Configuration Management.csv saved at: youtube_data\Configuration Management.csv
# -----------------------------------------------Scraping Complete (140/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Unit+Testing+Course
# Scrolling and get num_course: 14
# Video divs found 18
# Unit Testing.csv saved at: youtube_data\Unit Testing.csv
# -----------------------------------------------Scraping Complete (141/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Project+Management+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Project Management.csv saved at: youtube_data\Project Management.csv
# -----------------------------------------------Scraping Complete (142/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Database+Course
# Scrolling and get num_course: 9-9-9-9-9-9-28
# Video divs found 28
# Database.csv saved at: youtube_data\Database.csv
# -----------------------------------------------Scraping Complete (143/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Scrum+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Scrum.csv saved at: youtube_data\Scrum.csv
# -----------------------------------------------Scraping Complete (144/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Troubleshooting+Course
# Scrolling and get num_course: 14
# Video divs found 14
# Troubleshooting.csv saved at: youtube_data\Troubleshooting.csv
# -----------------------------------------------Scraping Complete (145/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=HTTP+Course
# Scrolling and get num_course: 18
# Video divs found 18
# HTTP.csv saved at: youtube_data\HTTP.csv
# -----------------------------------------------Scraping Complete (146/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Container+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Container.csv saved at: youtube_data\Container.csv
# -----------------------------------------------Scraping Complete (147/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Cloudformation+Course
# Scrolling and get num_course: 12
# Video divs found 14
# Cloudformation.csv saved at: youtube_data\Cloudformation.csv
# -----------------------------------------------Scraping Complete (148/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Cloud+Computing+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Cloud Computing.csv saved at: youtube_data\Cloud Computing.csv
# -----------------------------------------------Scraping Complete (149/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=React+Native+Course
# Scrolling and get num_course: 18
# Video divs found 18
# React Native.csv saved at: youtube_data\React Native.csv
# -----------------------------------------------Scraping Complete (150/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Objective+C+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Objective C.csv saved at: youtube_data\Objective C.csv
# -----------------------------------------------Scraping Complete (151/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=B+Testing+Course
# Scrolling and get num_course: 18
# Video divs found 18
# B Testing.csv saved at: youtube_data\B Testing.csv
# -----------------------------------------------Scraping Complete (152/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Site+Reliability+Engineering+Course
# Scrolling and get num_course: 16
# Video divs found 16
# Site Reliability Engineering.csv saved at: youtube_data\Site Reliability Engineering.csv
# -----------------------------------------------Scraping Complete (153/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=CSS3+Course
# Scrolling and get num_course: 15
# Video divs found 15
# CSS3.csv saved at: youtube_data\CSS3.csv
# -----------------------------------------------Scraping Complete (154/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Object-Oriented+Programming+Course
# Scrolling and get num_course: 14
# Video divs found 14
# Object-Oriented Programming.csv saved at: youtube_data\Object-Oriented Programming.csv
# -----------------------------------------------Scraping Complete (155/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Effective+Communication+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Effective Communication.csv saved at: youtube_data\Effective Communication.csv
# -----------------------------------------------Scraping Complete (156/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Flask+Course
# Scrolling and get num_course: 14
# Video divs found 14
# Flask.csv saved at: youtube_data\Flask.csv
# -----------------------------------------------Scraping Complete (157/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Redshift+Course
# Scrolling and get num_course: 16
# Video divs found 17
# Redshift.csv saved at: youtube_data\Redshift.csv
# ...
# Scraping URL: https://www.youtube.com/results?search_query=Technology+Architecture+Course
# Scrolling and get num_course: 13
# Video divs found 13
# Technology Architecture.csv saved at: youtube_data\Technology Architecture.csv
# -----------------------------------------------Scraping Complete (4572/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=low+level+firmware+programming+Course
# Scrolling and get num_course: 16
# Video divs found 16
# low level firmware programming.csv saved at: youtube_data\low level firmware programming.csv
# -----------------------------------------------Scraping Complete (4573/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=mixed-signal+circuits+Course
# Scrolling and get num_course: 17
# Video divs found 17
# mixed-signal circuits.csv saved at: youtube_data\mixed-signal circuits.csv
# -----------------------------------------------Scraping Complete (4574/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=OOP+design+concepts+Course
# Scrolling and get num_course: 17
# Video divs found 18
# OOP design concepts.csv saved at: youtube_data\OOP design concepts.csv
# -----------------------------------------------Scraping Complete (4575/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=8-bit+microprocessors+Course
# Scrolling and get num_course: 15
# Video divs found 15
# 8-bit microprocessors.csv saved at: youtube_data\8-bit microprocessors.csv
# -----------------------------------------------Scraping Complete (4576/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Defect+tracking+tools+Course
# Scrolling and get num_course: 19
# Video divs found 19
# Defect tracking tools.csv saved at: youtube_data\Defect tracking tools.csv
# -----------------------------------------------Scraping Complete (4577/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=ASP.NET+Web+API+Course
# Scrolling and get num_course: 5-5-5-5-5-5-20
# Video divs found 20
# ASP.NET Web API.csv saved at: youtube_data\ASP.NET Web API.csv
# -----------------------------------------------Scraping Complete (4578/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=automated+testing+and+deployment+Course
# Scrolling and get num_course: 20
# Video divs found 20
# automated testing and deployment.csv saved at: youtube_data\automated testing and deployment.csv
# -----------------------------------------------Scraping Complete (4579/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=AWS+platforms+including+SQS+Course
# Scrolling and get num_course: 20
# Video divs found 20
# AWS platforms including SQS.csv saved at: youtube_data\AWS platforms including SQS.csv
# -----------------------------------------------Scraping Complete (4580/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=SWF+Course
# Scrolling and get num_course: 20
# Video divs found 20
# SWF.csv saved at: youtube_data\SWF.csv
# -----------------------------------------------Scraping Complete (4581/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=and+RDS+Course
# Scrolling and get num_course: 20
# Video divs found 20
# and RDS.csv saved at: youtube_data\and RDS.csv
# -----------------------------------------------Scraping Complete (4582/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Document-oriented+Databases+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Document-oriented Databases.csv saved at: youtube_data\Document-oriented Databases.csv
# -----------------------------------------------Scraping Complete (4583/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Web+UI+Interactions+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Web UI Interactions.csv saved at: youtube_data\Web UI Interactions.csv
# -----------------------------------------------Scraping Complete (4584/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Fast+Healthcare+Interoperability+Resources+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Fast Healthcare Interoperability Resources.csv saved at: youtube_data\Fast Healthcare Interoperability Resources.csv
# -----------------------------------------------Scraping Complete (4585/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Java+Web+Services+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Java Web Services.csv saved at: youtube_data\Java Web Services.csv
# -----------------------------------------------Scraping Complete (4586/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Delegated+Authentication+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Delegated Authentication.csv saved at: youtube_data\Delegated Authentication.csv
# -----------------------------------------------Scraping Complete (4587/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Account+Provisioning+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Account Provisioning.csv saved at: youtube_data\Account Provisioning.csv
# -----------------------------------------------Scraping Complete (4588/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=PCI+Security+Standards+Course
# Scrolling and get num_course: 19
# Video divs found 19
# PCI Security Standards.csv saved at: youtube_data\PCI Security Standards.csv
# -----------------------------------------------Scraping Complete (4589/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=x509+Course
# Scrolling and get num_course: 8-20
# Video divs found 20
# x509.csv saved at: youtube_data\x509.csv
# -----------------------------------------------Scraping Complete (4590/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=WS-Security+Course
# Scrolling and get num_course: 18
# Video divs found 18
# WS-Security.csv saved at: youtube_data\WS-Security.csv
# -----------------------------------------------Scraping Complete (4591/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Configurable+Data+Security+Course
# Scrolling and get num_course: 18
# Video divs found 18
# Configurable Data Security.csv saved at: youtube_data\Configurable Data Security.csv
# -----------------------------------------------Scraping Complete (4592/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Identity+and+Access+Management+Course
# Scrolling and get num_course: 17
# Video divs found 17
# Identity and Access Management.csv saved at: youtube_data\Identity and Access Management.csv
# -----------------------------------------------Scraping Complete (4593/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Coding+Best+Practices+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Coding Best Practices.csv saved at: youtube_data\Coding Best Practices.csv
# -----------------------------------------------Scraping Complete (4594/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Cloud-based+infrastructure+platforms+Course
# Scrolling and get num_course: 20
# Video divs found 20
# Cloud-based infrastructure platforms.csv saved at: youtube_data\Cloud-based infrastructure platforms.csv
# -----------------------------------------------Scraping Complete (4595/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=OS+X+Course
# Scrolling and get num_course: 20
# Video divs found 20
# OS X.csv saved at: youtube_data\OS X.csv
# -----------------------------------------------Scraping Complete (4596/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Signal+Analysis+Course
# Scrolling and get num_course: 6-6-6-6-6-6-19
# Video divs found 19
# Signal Analysis.csv saved at: youtube_data\Signal Analysis.csv
# -----------------------------------------------Scraping Complete (4597/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=JavaScript-frameworks+Course
# Scrolling and get num_course: 20
# Video divs found 20
# JavaScript-frameworks.csv saved at: youtube_data\JavaScript-frameworks.csv
# -----------------------------------------------Scraping Complete (4598/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Realtime+Streaming+technologies+Course
# Scrolling and get num_course: 19
# Video divs found 19
# Realtime Streaming technologies.csv saved at: youtube_data\Realtime Streaming technologies.csv
# -----------------------------------------------Scraping Complete (4599/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=Arm+Core+microprocessors+Course
# Scrolling and get num_course: 15
# Video divs found 15
# Arm Core microprocessors.csv saved at: youtube_data\Arm Core microprocessors.csv
# -----------------------------------------------Scraping Complete (4600/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=SDK's+Course
# Scrolling and get num_course: 19
# Video divs found 19
# SDK's.csv saved at: youtube_data\SDK's.csv
# -----------------------------------------------Scraping Complete (4601/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=XMPP+Course
# Scrolling and get num_course: 20
# Video divs found 20
# XMPP.csv saved at: youtube_data\XMPP.csv
# -----------------------------------------------Scraping Complete (4602/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=AWS+IOT+Course
# Scrolling and get num_course: 18
# Video divs found 18
# AWS IOT.csv saved at: youtube_data\AWS IOT.csv
# -----------------------------------------------Scraping Complete (4603/9481)-----------------------------------------------
# Scraping URL: https://www.youtube.com/results?search_query=network+security+techniques+Course
# Scrolling and get num_course: 17
# Video divs found 17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 101
#      99 except:
#     100     None
# --> 101 soup = BeautifulSoup(driver.page_source, 'html.parser')
#     102 video_divs = soup.find_all('ytd-video-renderer', class_= "style-scope ytd-item-section-renderer")[:num_videos]
#     104 # Get skill name
#
# File d:\我的堆\vscode_workspace\243-Career-Roadmap\backend\venv\Lib\site-packages\bs4\__init__.py:325, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     323 self.reset()
#     324 try:
# --> 325     self._feed()
#     326     success = True
#     327     break
#
# File d:\我的堆\vscode_workspace\243-Career-Roadmap\backend\venv\Lib\site-packages\bs4\__init__.py:399, in BeautifulSoup._feed(self)
#     396 # Convert the document to Unicode.
#     397 self.builder.reset()
# --> 399 self.builder.feed(self.markup)
#     400 # Close out any unfinished strings and close all the open tags.
#     401 self.endData()
#
# File d:\我的堆\vscode_workspace\243-Career-Roadmap\backend\venv\Lib\site-packages\bs4\builder\_htmlparser.py:339, in HTMLParserTreeBuilder.feed(self, markup)
#     337 parser.soup = self.soup
#     338 try:
# --> 339     parser.feed(markup)
#     340     parser.close()
#     341 except HTMLParseError as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\html\parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\html\parser.py:337, in HTMLParser.parse_starttag(self, i)
#     335     self.handle_startendtag(tag, attrs)
#     336 else:
# --> 337     self.handle_starttag(tag, attrs)
#     338     if tag in self.CDATA_CONTENT_ELEMENTS:
#     339         self.set_cdata_mode(tag)
#
# File d:\我的堆\vscode_workspace\243-Career-Roadmap\backend\venv\Lib\site-packages\bs4\builder\_htmlparser.py:121, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     119 #print "START", name
#     120 sourceline, sourcepos = self.getpos()
# --> 121 tag = self.soup.handle_starttag(
#     122     name, None, None, attr_dict, sourceline=sourceline,
#     123     sourcepos=sourcepos
#     124 )
#     125 if tag and tag.is_empty_element and handle_empty_element:
#     126     # Unlike other parsers, html.parser doesn't send separate end tag
#     127     # events for empty-element tags. (It's handled in
#    (...)    133     # don't want handle_endtag() to cross off any previous end
#     134     # events for tags of this name.
#     135     self.handle_endtag(name, check_already_closed=False)
#
# File d:\我的堆\vscode_workspace\243-Career-Roadmap\backend\venv\Lib\site-packages\bs4\__init__.py:631, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     626 if (self.parse_only and len(self.tagStack) <= 1
#     627     and (self.parse_only.text
#     628          or not self.parse_only.search_tag(name, attrs))):
#     629     return None
# --> 631 tag = self.element_classes.get(Tag, Tag)(
#     632     self, self.builder, name, namespace, nsprefix, attrs,
#     633     self.currentTag, self._most_recent_element,
#     634     sourceline=sourceline, sourcepos=sourcepos
#     635 )
#     636 if tag is None:
#     637     return tag
#
# File d:\我的堆\vscode_workspace\243-Career-Roadmap\backend\venv\Lib\site-packages\bs4\element.py:1039, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags)
#    1037 elif attrs:
#    1038     if builder is not None and builder.cdata_list_attributes:
# -> 1039         attrs = builder._replace_cdata_list_attribute_values(
#    1040             self.name, attrs)
#    1041     else:
#    1042         attrs = dict(attrs)
#
# File d:\我的堆\vscode_workspace\243-Career-Roadmap\backend\venv\Lib\site-packages\bs4\builder\__init__.py:284, in TreeBuilder._replace_cdata_list_attribute_values(self, tag_name, attrs)
#     281 universal = self.cdata_list_attributes.get('*', [])
#     282 tag_specific = self.cdata_list_attributes.get(
#     283     tag_name.lower(), None)
# --> 284 for attr in list(attrs.keys()):
#     285     if attr in universal or (tag_specific and attr in tag_specific):
#     286         # We have a "class"-type attribute whose string
#     287         # value is a whitespace-separated list of
#     288         # values. Split it into a list.
#     289         value = attrs[attr]
#
# KeyboardInterrupt:
