# %%
import json
import os
import time
import urllib.parse
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait
import re

# Setup Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--lang=en-US")  # Force browser to load English
options.add_argument("--headless")  # Run in headless mode (no GUI)
options.add_argument("--disable-gpu")
options.add_argument("--window-size=1920,1080")
options.add_argument("--log-level=3")  # Suppress logs

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# --------------------------------------------------------------------------------------------------------------------------
# Search skills: what skills do you want to get course data on
# --------------------------------------------------------------------------------------------------------------------------
# Specify the path to the file containing the extracted skills
with open("job_domain_skills.json", "r", encoding="utf-8") as f:
    job_domain_skills = json.load(f)

url_list = []

for job, skills in job_domain_skills.items():
    for skill in skills:
        url = "https://www.youtube.com/results?search_query="+"Course+"+skill.replace(" ","+")+"+"+skill.replace(" ","+")+"+"+job
        url_list.append([job, skill, url])

latest_url_index = 0


data_folder = "youtube_data"
os.makedirs(data_folder, exist_ok=True)  # Ensure folder exists

# Function to scroll down to load dynamic content
def scroll_page(n,target_tag, target_class):
    """scroll page utill there are n course cards or no new contents are loaded"""
    num_video = len(driver.find_elements(By.CSS_SELECTOR, target_tag+'.'+target_class.replace(" ", ".")))
    no_new_scroll = 0
    print(f"Scrolling and get num_course: {num_video}",end="")
    while num_video < n and no_new_scroll < 10:  # Adjust range as needed
        driver.execute_script("window.scrollBy(0, 1500);")
        time.sleep(1.5)# Wait for content to load
        new_num_video = len(driver.find_elements(By.CSS_SELECTOR, target_tag+'.'+target_class.replace(" ", ".")))
        print(f"-{new_num_video}",end="")
        if new_num_video > num_video:
            no_new_scroll = 0
            num_video = new_num_video
        else:
            no_new_scroll += 1
    print('')
    
data = []

for idx, ls in enumerate(url_list[latest_url_index:]):
    job = ls[0]
    skill = ls[1]
    url = ls[2]
    print(job, skill)
    try:
        print(f"Scraping URL: {url}")
        driver.get(url)
        while not driver.page_source:
            time.sleep(3)# Wait for initial load
        target_tag = 'ytd-video-renderer'
        target_class = "style-scope ytd-item-section-renderer"
        # ------------------------------------------------------------------------------------------------------------------
        # Scroll page; change number of courses you want to scroll and scrape for each skill
        # ------------------------------------------------------------------------------------------------------------------
        # scroll_page(10,target_tag,target_class)
    except Exception as e:
        print(f"Failed to scrape {url}: {e}")

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find all product containers
    video_divs = soup.find_all('ytd-video-renderer', class_= "style-scope ytd-item-section-renderer")
    num_videos = len(video_divs)
    print(f"Video divs found {num_videos}")

    def thumbnails_loaded(driver):
        driver.execute_script("window.scrollBy(0, 1500);")
        video_divs = driver.find_elements(By.CSS_SELECTOR, "ytd-video-renderer.style-scope.ytd-item-section-renderer")  # Refresh the list in case of updates
        count = 0
        for video in video_divs[:num_videos]:
            if video:
                thumbnail = video.find_elements(By.CSS_SELECTOR, "a#thumbnail.yt-simple-endpoint.inline-block.style-scope.ytd-thumbnail img.yt-core-image--loaded")
                if thumbnail:
                    count += 1
        return count >= num_videos
    try:
        WebDriverWait(driver, 5).until(thumbnails_loaded)
    except:
        None
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    video_divs = soup.find_all('ytd-video-renderer', class_= "style-scope ytd-item-section-renderer")[:num_videos]
    
    # Extract information
    video = []
    for div in video_divs:
        if div:
            # Extract video link
            video_tag = div.find("a", attrs={"class": "yt-simple-endpoint inline-block style-scope ytd-thumbnail", "id": "thumbnail"})
            video_link = "https://youtube.com"+video_tag.get("href") if video_tag else None
            thumbnail_tag = video_tag.find("img") if video_tag else None
            thumbnail_link = thumbnail_tag.get("src") if thumbnail_tag else None

            # Extract video title
            title_div =div.find("a", attrs={"class": "yt-simple-endpoint style-scope ytd-video-renderer", "id": "video-title"})
            title_tag = title_div.find("yt-formatted-string", class_="style-scope ytd-video-renderer") if title_div else None
            title = title_tag.text.strip() if title_tag else None

            # Extract num_views and video age
            num_views_div = div.find("div", attrs={"class": "style-scope ytd-video-meta-block", "id": "metadata-line"})
            metadata_items = [span.text for span in num_views_div.find_all("span")] if num_views_div else None
            if metadata_items and len(metadata_items) >= 2:
                num_views, age = metadata_items[0], metadata_items[1]
                if not age.endswith("ago"):
                    num_views, age = age, num_views  # Swap values if needed
            elif metadata_items and len(metadata_items) == 1:
                if "ago" in metadata_items[0]:
                    num_views, age = None, metadata_items[0]  # It's age, set views to None
                else:
                    num_views, age = metadata_items[0], None  # It's views, set age to None
            else:
                num_views, age = None, None

            # Extract channel name
            channel_tag = div.find("yt-formatted-string", attrs={"class": "style-scope ytd-channel-name", "id": "text"})
            channel = channel_tag.text.strip() if channel_tag else None

            # Extract video snippet
            snippet_div = div.find("yt-formatted-string", class_="metadata-snippet-text style-scope ytd-video-renderer")
            snippet_tag = snippet_div.find_all("span") if snippet_div else None
            snippet = " ".join(span.text.strip() for span in snippet_tag) if snippet_tag else None
            
            # Extract video duration
            duration_tag = div.find("span", attrs={"class": "style-scope ytd-thumbnail-overlay-time-status-renderer", "id": "text"})
            duration = duration_tag.text.strip() if duration_tag else None
            
            # Extract course series
            series_div = div.find("div", attrs={"class": "style-scope ytd-expandable-metadata-renderer", "id": "header"})
            chapter_div = series_div.find("yt-formatted-string",\
                          attrs={"class": "style-scope ytd-expandable-metadata-renderer", "id": "prominent-label-text"})\
                          if series_div else None
            chapter_tag = chapter_div.find("span") if chapter_div else None
            chapter = chapter_tag.text.strip() if chapter_tag else None
            series_div2 = series_div.find("div", attrs={"class": "style-scope ytd-expandable-metadata-renderer", "id": "collapsed-title"})\
                          if series_div else None
            text_tag = series_div2.find("yt-formatted-string") if series_div2 else None
            text = text_tag.text if text_tag else None
            topics = text.split(" | ") if text else None
            series = [re.sub(r"^\d+\.", "", topic).strip() for topic in topics] if topics else None

            
            # Append extracted data
            video.append({
                'skill': skill,
                'thumbnail_link': thumbnail_link,
                'video_link': video_link,
                'title': title,
                'num_views': num_views,
                'age': age,
                'channel': channel,
                'snippet': snippet,
                'duration': duration,
                'chapter': chapter,
                'series': series
            })
    df = pd.DataFrame(video)
    skillname = skill.replace("/", "_").replace("*", "_")
    csv_path = os.path.join(data_folder, f"{skillname}.csv")
    df.to_csv(csv_path, index=False)
    print(f"{skillname}.csv saved at: {csv_path}")
    print(f"-----------------------------------------------Scraping Complete Index ({latest_url_index+idx}/{len(url_list)-1})-----------------------------------------------")
            
# Close the driver after scraping
driver.quit()
# Out:
# Business Analyst .net
# Scraping URL: https://www.youtube.com/results?search_query=Course+.net+.net+Business Analyst
# Video divs found 20
# .net.csv saved at: youtube_data\.net.csv
# -----------------------------------------------Scraping Complete Index (0/2666)-----------------------------------------------
# Business Analyst .net frameworks
# Scraping URL: https://www.youtube.com/results?search_query=Course+.net+frameworks+.net+frameworks+Business Analyst
# Video divs found 4
# .net frameworks.csv saved at: youtube_data\.net frameworks.csv
# -----------------------------------------------Scraping Complete Index (1/2666)-----------------------------------------------
# Business Analyst a/b testing
# Scraping URL: https://www.youtube.com/results?search_query=Course+a/b+testing+a/b+testing+Business Analyst
# Video divs found 19
# a_b testing.csv saved at: youtube_data\a_b testing.csv
# -----------------------------------------------Scraping Complete Index (2/2666)-----------------------------------------------
# Business Analyst abap
# Scraping URL: https://www.youtube.com/results?search_query=Course+abap+abap+Business Analyst
# Video divs found 19
# abap.csv saved at: youtube_data\abap.csv
# -----------------------------------------------Scraping Complete Index (3/2666)-----------------------------------------------
# Business Analyst access
# Scraping URL: https://www.youtube.com/results?search_query=Course+access+access+Business Analyst
# Video divs found 20
# access.csv saved at: youtube_data\access.csv
# -----------------------------------------------Scraping Complete Index (4/2666)-----------------------------------------------
# Business Analyst active directory
# Scraping URL: https://www.youtube.com/results?search_query=Course+active+directory+active+directory+Business Analyst
# Video divs found 12
# active directory.csv saved at: youtube_data\active directory.csv
# -----------------------------------------------Scraping Complete Index (5/2666)-----------------------------------------------
# Business Analyst agile
# Scraping URL: https://www.youtube.com/results?search_query=Course+agile+agile+Business Analyst
# Video divs found 18
# agile.csv saved at: youtube_data\agile.csv
# -----------------------------------------------Scraping Complete Index (6/2666)-----------------------------------------------
# Business Analyst agile development
# Scraping URL: https://www.youtube.com/results?search_query=Course+agile+development+agile+development+Business Analyst
# Video divs found 20
# agile development.csv saved at: youtube_data\agile development.csv
# -----------------------------------------------Scraping Complete Index (7/2666)-----------------------------------------------
# Business Analyst alteryx
# Scraping URL: https://www.youtube.com/results?search_query=Course+alteryx+alteryx+Business Analyst
# Video divs found 18
# alteryx.csv saved at: youtube_data\alteryx.csv
# -----------------------------------------------Scraping Complete Index (8/2666)-----------------------------------------------
# Business Analyst analytical skills
# Scraping URL: https://www.youtube.com/results?search_query=Course+analytical+skills+analytical+skills+Business Analyst
# Video divs found 14
# analytical skills.csv saved at: youtube_data\analytical skills.csv
# -----------------------------------------------Scraping Complete Index (9/2666)-----------------------------------------------
# Business Analyst analytics
# Scraping URL: https://www.youtube.com/results?search_query=Course+analytics+analytics+Business Analyst
# Video divs found 20
# analytics.csv saved at: youtube_data\analytics.csv
# -----------------------------------------------Scraping Complete Index (10/2666)-----------------------------------------------
# Business Analyst angular
# Scraping URL: https://www.youtube.com/results?search_query=Course+angular+angular+Business Analyst
# Video divs found 18
# angular.csv saved at: youtube_data\angular.csv
# -----------------------------------------------Scraping Complete Index (11/2666)-----------------------------------------------
# Business Analyst api
# Scraping URL: https://www.youtube.com/results?search_query=Course+api+api+Business Analyst
# Video divs found 11
# api.csv saved at: youtube_data\api.csv
# -----------------------------------------------Scraping Complete Index (12/2666)-----------------------------------------------
# Business Analyst apo - advanced planning and optimization
# Scraping URL: https://www.youtube.com/results?search_query=Course+apo+-+advanced+planning+and+optimization+apo+-+advanced+planning+and+optimization+Business Analyst
# Video divs found 20
# apo - advanced planning and optimization.csv saved at: youtube_data\apo - advanced planning and optimization.csv
# -----------------------------------------------Scraping Complete Index (13/2666)-----------------------------------------------
# Business Analyst ariba
# Scraping URL: https://www.youtube.com/results?search_query=Course+ariba+ariba+Business Analyst
# Video divs found 18
# ariba.csv saved at: youtube_data\ariba.csv
# -----------------------------------------------Scraping Complete Index (14/2666)-----------------------------------------------
# Business Analyst asp.net
# Scraping URL: https://www.youtube.com/results?search_query=Course+asp.net+asp.net+Business Analyst
# Video divs found 16
# asp.net.csv saved at: youtube_data\asp.net.csv
# -----------------------------------------------Scraping Complete Index (15/2666)-----------------------------------------------
# Business Analyst aws
# Scraping URL: https://www.youtube.com/results?search_query=Course+aws+aws+Business Analyst
# Video divs found 19
# aws.csv saved at: youtube_data\aws.csv
# -----------------------------------------------Scraping Complete Index (16/2666)-----------------------------------------------
# Business Analyst azure
# Scraping URL: https://www.youtube.com/results?search_query=Course+azure+azure+Business Analyst
# Video divs found 19
# azure.csv saved at: youtube_data\azure.csv
# -----------------------------------------------Scraping Complete Index (17/2666)-----------------------------------------------
# Business Analyst bi tool
# Scraping URL: https://www.youtube.com/results?search_query=Course+bi+tool+bi+tool+Business Analyst
# Video divs found 20
# bi tool.csv saved at: youtube_data\bi tool.csv
# -----------------------------------------------Scraping Complete Index (18/2666)-----------------------------------------------
# Business Analyst big data
# Scraping URL: https://www.youtube.com/results?search_query=Course+big+data+big+data+Business Analyst
# Video divs found 19
# big data.csv saved at: youtube_data\big data.csv
# -----------------------------------------------Scraping Complete Index (19/2666)-----------------------------------------------
# Business Analyst business analysis
# Scraping URL: https://www.youtube.com/results?search_query=Course+business+analysis+business+analysis+Business Analyst
# Video divs found 16
# business analysis.csv saved at: youtube_data\business analysis.csv
# -----------------------------------------------Scraping Complete Index (20/2666)-----------------------------------------------
# Business Analyst business analyst
# Scraping URL: https://www.youtube.com/results?search_query=Course+business+analyst+business+analyst+Business Analyst
# Video divs found 20
# business analyst.csv saved at: youtube_data\business analyst.csv
# -----------------------------------------------Scraping Complete Index (21/2666)-----------------------------------------------
# Business Analyst business intelligence
# Scraping URL: https://www.youtube.com/results?search_query=Course+business+intelligence+business+intelligence+Business Analyst
# Video divs found 17
# business intelligence.csv saved at: youtube_data\business intelligence.csv
# -----------------------------------------------Scraping Complete Index (22/2666)-----------------------------------------------
# Business Analyst business intelligence tools
# Scraping URL: https://www.youtube.com/results?search_query=Course+business+intelligence+tools+business+intelligence+tools+Business Analyst
# Video divs found 20
# business intelligence tools.csv saved at: youtube_data\business intelligence tools.csv
# -----------------------------------------------Scraping Complete Index (23/2666)-----------------------------------------------
# Business Analyst business object
# Scraping URL: https://www.youtube.com/results?search_query=Course+business+object+business+object+Business Analyst
# Video divs found 18
# business object.csv saved at: youtube_data\business object.csv
# -----------------------------------------------Scraping Complete Index (24/2666)-----------------------------------------------
# Business Analyst c#
# Scraping URL: https://www.youtube.com/results?search_query=Course+c#+c#+Business Analyst
# Video divs found 6
# c#.csv saved at: youtube_data\c#.csv
# -----------------------------------------------Scraping Complete Index (25/2666)-----------------------------------------------
# Business Analyst c++
# Scraping URL: https://www.youtube.com/results?search_query=Course+c+++c+++Business Analyst
# Video divs found 20
# c++.csv saved at: youtube_data\c++.csv
# -----------------------------------------------Scraping Complete Index (26/2666)-----------------------------------------------
# Business Analyst cassandra
# Scraping URL: https://www.youtube.com/results?search_query=Course+cassandra+cassandra+Business Analyst
# Video divs found 11
# cassandra.csv saved at: youtube_data\cassandra.csv
# -----------------------------------------------Scraping Complete Index (27/2666)-----------------------------------------------
# Business Analyst cissp
# Scraping URL: https://www.youtube.com/results?search_query=Course+cissp+cissp+Business Analyst
# Video divs found 15
# cissp.csv saved at: youtube_data\cissp.csv
# -----------------------------------------------Scraping Complete Index (28/2666)-----------------------------------------------
# Business Analyst cloud
# Scraping URL: https://www.youtube.com/results?search_query=Course+cloud+cloud+Business Analyst
# Video divs found 17
# cloud.csv saved at: youtube_data\cloud.csv
# -----------------------------------------------Scraping Complete Index (29/2666)-----------------------------------------------
# Business Analyst cloud based technologies
# Scraping URL: https://www.youtube.com/results?search_query=Course+cloud+based+technologies+cloud+based+technologies+Business Analyst
# Video divs found 20
# cloud based technologies.csv saved at: youtube_data\cloud based technologies.csv
# -----------------------------------------------Scraping Complete Index (30/2666)-----------------------------------------------
# Business Analyst cognos
# Scraping URL: https://www.youtube.com/results?search_query=Course+cognos+cognos+Business Analyst
# Video divs found 2
# cognos.csv saved at: youtube_data\cognos.csv
# -----------------------------------------------Scraping Complete Index (31/2666)-----------------------------------------------
# Business Analyst communication skills
# Scraping URL: https://www.youtube.com/results?search_query=Course+communication+skills+communication+skills+Business Analyst
# Video divs found 20
# communication skills.csv saved at: youtube_data\communication skills.csv
# -----------------------------------------------Scraping Complete Index (32/2666)-----------------------------------------------
# Business Analyst configuration
# Scraping URL: https://www.youtube.com/results?search_query=Course+configuration+configuration+Business Analyst
# Video divs found 10
# configuration.csv saved at: youtube_data\configuration.csv
# -----------------------------------------------Scraping Complete Index (33/2666)-----------------------------------------------
# Business Analyst configuration and design
# Scraping URL: https://www.youtube.com/results?search_query=Course+configuration+and+design+configuration+and+design+Business Analyst
# Video divs found 4
# configuration and design.csv saved at: youtube_data\configuration and design.csv
# -----------------------------------------------Scraping Complete Index (34/2666)-----------------------------------------------
# Business Analyst crm
# Scraping URL: https://www.youtube.com/results?search_query=Course+crm+crm+Business Analyst
# Video divs found 13
# crm.csv saved at: youtube_data\crm.csv
# -----------------------------------------------Scraping Complete Index (35/2666)-----------------------------------------------
# Business Analyst crystal reports
# Scraping URL: https://www.youtube.com/results?search_query=Course+crystal+reports+crystal+reports+Business Analyst
# Video divs found 1
# crystal reports.csv saved at: youtube_data\crystal reports.csv
# -----------------------------------------------Scraping Complete Index (36/2666)-----------------------------------------------
# Business Analyst css
# Scraping URL: https://www.youtube.com/results?search_query=Course+css+css+Business Analyst
# Video divs found 5
# css.csv saved at: youtube_data\css.csv
# -----------------------------------------------Scraping Complete Index (37/2666)-----------------------------------------------
# Business Analyst data analysis
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+analysis+data+analysis+Business Analyst
# Video divs found 10
# data analysis.csv saved at: youtube_data\data analysis.csv
# -----------------------------------------------Scraping Complete Index (38/2666)-----------------------------------------------
# Business Analyst data analytics
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+analytics+data+analytics+Business Analyst
# Video divs found 9
# data analytics.csv saved at: youtube_data\data analytics.csv
# -----------------------------------------------Scraping Complete Index (39/2666)-----------------------------------------------
# Business Analyst data governance
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+governance+data+governance+Business Analyst
# Video divs found 19
# data governance.csv saved at: youtube_data\data governance.csv
# -----------------------------------------------Scraping Complete Index (40/2666)-----------------------------------------------
# Business Analyst data integration
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+integration+data+integration+Business Analyst
# Video divs found 10
# data integration.csv saved at: youtube_data\data integration.csv
# -----------------------------------------------Scraping Complete Index (41/2666)-----------------------------------------------
# Business Analyst data mapping
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+mapping+data+mapping+Business Analyst
# Video divs found 19
# data mapping.csv saved at: youtube_data\data mapping.csv
# -----------------------------------------------Scraping Complete Index (42/2666)-----------------------------------------------
# Business Analyst data migration
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+migration+data+migration+Business Analyst
# Video divs found 15
# data migration.csv saved at: youtube_data\data migration.csv
# -----------------------------------------------Scraping Complete Index (43/2666)-----------------------------------------------
# Business Analyst data mining
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+mining+data+mining+Business Analyst
# Video divs found 14
# data mining.csv saved at: youtube_data\data mining.csv
# -----------------------------------------------Scraping Complete Index (44/2666)-----------------------------------------------
# Business Analyst data modeling
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+modeling+data+modeling+Business Analyst
# Video divs found 19
# data modeling.csv saved at: youtube_data\data modeling.csv
# -----------------------------------------------Scraping Complete Index (45/2666)-----------------------------------------------
# Business Analyst data quality
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+quality+data+quality+Business Analyst
# Video divs found 20
# data quality.csv saved at: youtube_data\data quality.csv
# -----------------------------------------------Scraping Complete Index (46/2666)-----------------------------------------------
# Business Analyst data science
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+science+data+science+Business Analyst
# Video divs found 20
# data science.csv saved at: youtube_data\data science.csv
# -----------------------------------------------Scraping Complete Index (47/2666)-----------------------------------------------
# Business Analyst data visualization
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+visualization+data+visualization+Business Analyst
# Video divs found 20
# data visualization.csv saved at: youtube_data\data visualization.csv
# -----------------------------------------------Scraping Complete Index (48/2666)-----------------------------------------------
# Business Analyst data warehouse
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+warehouse+data+warehouse+Business Analyst
# Video divs found 9
# data warehouse.csv saved at: youtube_data\data warehouse.csv
# -----------------------------------------------Scraping Complete Index (49/2666)-----------------------------------------------
# Business Analyst data warehousing
# Scraping URL: https://www.youtube.com/results?search_query=Course+data+warehousing+data+warehousing+Business Analyst
# Video divs found 16
# data warehousing.csv saved at: youtube_data\data warehousing.csv
# -----------------------------------------------Scraping Complete Index (50/2666)-----------------------------------------------
# Business Analyst database
# Scraping URL: https://www.youtube.com/results?search_query=Course+database+database+Business Analyst
# Video divs found 20
# database.csv saved at: youtube_data\database.csv
# -----------------------------------------------Scraping Complete Index (51/2666)-----------------------------------------------
# Business Analyst database concepts
# Scraping URL: https://www.youtube.com/results?search_query=Course+database+concepts+database+concepts+Business Analyst
# Video divs found 16
# database concepts.csv saved at: youtube_data\database concepts.csv
# -----------------------------------------------Scraping Complete Index (52/2666)-----------------------------------------------
# Business Analyst db2
# Scraping URL: https://www.youtube.com/results?search_query=Course+db2+db2+Business Analyst
# Video divs found 18
# db2.csv saved at: youtube_data\db2.csv
# -----------------------------------------------Scraping Complete Index (53/2666)-----------------------------------------------
# Business Analyst deep learning
# Scraping URL: https://www.youtube.com/results?search_query=Course+deep+learning+deep+learning+Business Analyst
# Video divs found 17
# deep learning.csv saved at: youtube_data\deep learning.csv
# -----------------------------------------------Scraping Complete Index (54/2666)-----------------------------------------------
# Business Analyst designing
# Scraping URL: https://www.youtube.com/results?search_query=Course+designing+designing+Business Analyst
# Video divs found 10
# designing.csv saved at: youtube_data\designing.csv
# -----------------------------------------------Scraping Complete Index (55/2666)-----------------------------------------------
# Business Analyst designing and prototyping
# Scraping URL: https://www.youtube.com/results?search_query=Course+designing+and+prototyping+designing+and+prototyping+Business Analyst
# Video divs found 20
# designing and prototyping.csv saved at: youtube_data\designing and prototyping.csv
# -----------------------------------------------Scraping Complete Index (56/2666)-----------------------------------------------
# Business Analyst devops
# Scraping URL: https://www.youtube.com/results?search_query=Course+devops+devops+Business Analyst
# Video divs found 19
# devops.csv saved at: youtube_data\devops.csv
# -----------------------------------------------Scraping Complete Index (57/2666)-----------------------------------------------
# Business Analyst dimensional modeling
# Scraping URL: https://www.youtube.com/results?search_query=Course+dimensional+modeling+dimensional+modeling+Business Analyst
# Video divs found 20
# dimensional modeling.csv saved at: youtube_data\dimensional modeling.csv
# -----------------------------------------------Scraping Complete Index (58/2666)-----------------------------------------------
# Business Analyst documentation
# Scraping URL: https://www.youtube.com/results?search_query=Course+documentation+documentation+Business Analyst
# Video divs found 18
# documentation.csv saved at: youtube_data\documentation.csv
# -----------------------------------------------Scraping Complete Index (59/2666)-----------------------------------------------
# Business Analyst edi
# Scraping URL: https://www.youtube.com/results?search_query=Course+edi+edi+Business Analyst
# Video divs found 11
# edi.csv saved at: youtube_data\edi.csv
# -----------------------------------------------Scraping Complete Index (60/2666)-----------------------------------------------
# Business Analyst erp
# Scraping URL: https://www.youtube.com/results?search_query=Course+erp+erp+Business Analyst
# Video divs found 19
# erp.csv saved at: youtube_data\erp.csv
# -----------------------------------------------Scraping Complete Index (61/2666)-----------------------------------------------
# Business Analyst etl
# Scraping URL: https://www.youtube.com/results?search_query=Course+etl+etl+Business Analyst
# Video divs found 15
# etl.csv saved at: youtube_data\etl.csv
# -----------------------------------------------Scraping Complete Index (62/2666)-----------------------------------------------
# Business Analyst etl development
# Scraping URL: https://www.youtube.com/results?search_query=Course+etl+development+etl+development+Business Analyst
# Video divs found 10
# etl development.csv saved at: youtube_data\etl development.csv
# -----------------------------------------------Scraping Complete Index (63/2666)-----------------------------------------------
# Business Analyst etl tool
# Scraping URL: https://www.youtube.com/results?search_query=Course+etl+tool+etl+tool+Business Analyst
# Video divs found 19
# etl tool.csv saved at: youtube_data\etl tool.csv
# -----------------------------------------------Scraping Complete Index (64/2666)-----------------------------------------------
# Business Analyst ewm - extended warehouse management
# Scraping URL: https://www.youtube.com/results?search_query=Course+ewm+-+extended+warehouse+management+ewm+-+extended+warehouse+management+Business Analyst
# Video divs found 9
# ewm - extended warehouse management.csv saved at: youtube_data\ewm - extended warehouse management.csv
# -----------------------------------------------Scraping Complete Index (65/2666)-----------------------------------------------
# Business Analyst excel
# Scraping URL: https://www.youtube.com/results?search_query=Course+excel+excel+Business Analyst
# Video divs found 5
# excel.csv saved at: youtube_data\excel.csv
# -----------------------------------------------Scraping Complete Index (66/2666)-----------------------------------------------
# Business Analyst financial modeling
# Scraping URL: https://www.youtube.com/results?search_query=Course+financial+modeling+financial+modeling+Business Analyst
# Video divs found 7
# financial modeling.csv saved at: youtube_data\financial modeling.csv
# -----------------------------------------------Scraping Complete Index (67/2666)-----------------------------------------------
# Business Analyst functional specification
# Scraping URL: https://www.youtube.com/results?search_query=Course+functional+specification+functional+specification+Business Analyst
# Video divs found 10
# functional specification.csv saved at: youtube_data\functional specification.csv
# -----------------------------------------------Scraping Complete Index (68/2666)-----------------------------------------------
# Business Analyst git
# Scraping URL: https://www.youtube.com/results?search_query=Course+git+git+Business Analyst
# Video divs found 18
# git.csv saved at: youtube_data\git.csv
# -----------------------------------------------Scraping Complete Index (69/2666)-----------------------------------------------
# Business Analyst google analytics
# Scraping URL: https://www.youtube.com/results?search_query=Course+google+analytics+google+analytics+Business Analyst
# Video divs found 15
# google analytics.csv saved at: youtube_data\google analytics.csv
# -----------------------------------------------Scraping Complete Index (70/2666)-----------------------------------------------
# Business Analyst hadoop
# Scraping URL: https://www.youtube.com/results?search_query=Course+hadoop+hadoop+Business Analyst
# Video divs found 20
# hadoop.csv saved at: youtube_data\hadoop.csv
# -----------------------------------------------Scraping Complete Index (71/2666)-----------------------------------------------
# Business Analyst hana
# Scraping URL: https://www.youtube.com/results?search_query=Course+hana+hana+Business Analyst
# Video divs found 13
# hana.csv saved at: youtube_data\hana.csv
# -----------------------------------------------Scraping Complete Index (72/2666)-----------------------------------------------
# Business Analyst hibernate
# Scraping URL: https://www.youtube.com/results?search_query=Course+hibernate+hibernate+Business Analyst
# Video divs found 10
# hibernate.csv saved at: youtube_data\hibernate.csv
# -----------------------------------------------Scraping Complete Index (73/2666)-----------------------------------------------
# Business Analyst hive
# Scraping URL: https://www.youtube.com/results?search_query=Course+hive+hive+Business Analyst
# Video divs found 3
# hive.csv saved at: youtube_data\hive.csv
# -----------------------------------------------Scraping Complete Index (74/2666)-----------------------------------------------
# Business Analyst html
# Scraping URL: https://www.youtube.com/results?search_query=Course+html+html+Business Analyst
# Video divs found 10
# html.csv saved at: youtube_data\html.csv
# -----------------------------------------------Scraping Complete Index (75/2666)-----------------------------------------------
# Business Analyst html 5
# Scraping URL: https://www.youtube.com/results?search_query=Course+html+5+html+5+Business Analyst
# Video divs found 9
# html 5.csv saved at: youtube_data\html 5.csv
# -----------------------------------------------Scraping Complete Index (76/2666)-----------------------------------------------
# Business Analyst html5
# Scraping URL: https://www.youtube.com/results?search_query=Course+html5+html5+Business Analyst
# Video divs found 16
# html5.csv saved at: youtube_data\html5.csv
# -----------------------------------------------Scraping Complete Index (77/2666)-----------------------------------------------
# Business Analyst ibp - integrated business planning
# Scraping URL: https://www.youtube.com/results?search_query=Course+ibp+-+integrated+business+planning+ibp+-+integrated+business+planning+Business Analyst
# Video divs found 7
# ibp - integrated business planning.csv saved at: youtube_data\ibp - integrated business planning.csv
# -----------------------------------------------Scraping Complete Index (78/2666)-----------------------------------------------
# Business Analyst informatica
# Scraping URL: https://www.youtube.com/results?search_query=Course+informatica+informatica+Business Analyst
# Video divs found 18
# informatica.csv saved at: youtube_data\informatica.csv
# -----------------------------------------------Scraping Complete Index (79/2666)-----------------------------------------------
# Business Analyst infrastructure
# Scraping URL: https://www.youtube.com/results?search_query=Course+infrastructure+infrastructure+Business Analyst
# Video divs found 10
# infrastructure.csv saved at: youtube_data\infrastructure.csv
# -----------------------------------------------Scraping Complete Index (80/2666)-----------------------------------------------
# Business Analyst integration
# Scraping URL: https://www.youtube.com/results?search_query=Course+integration+integration+Business Analyst
# Video divs found 10
# integration.csv saved at: youtube_data\integration.csv
# -----------------------------------------------Scraping Complete Index (81/2666)-----------------------------------------------
# Business Analyst itil
# Scraping URL: https://www.youtube.com/results?search_query=Course+itil+itil+Business Analyst
# Video divs found 10
# itil.csv saved at: youtube_data\itil.csv
# -----------------------------------------------Scraping Complete Index (82/2666)-----------------------------------------------
# Business Analyst java
# Scraping URL: https://www.youtube.com/results?search_query=Course+java+java+Business Analyst
# Video divs found 10
# java.csv saved at: youtube_data\java.csv
# -----------------------------------------------Scraping Complete Index (83/2666)-----------------------------------------------
# Business Analyst jira
# Scraping URL: https://www.youtube.com/results?search_query=Course+jira+jira+Business Analyst
# Video divs found 9
# jira.csv saved at: youtube_data\jira.csv
# -----------------------------------------------Scraping Complete Index (84/2666)-----------------------------------------------
# Business Analyst jquery
# Scraping URL: https://www.youtube.com/results?search_query=Course+jquery+jquery+Business Analyst
# Video divs found 10
# jquery.csv saved at: youtube_data\jquery.csv
# -----------------------------------------------Scraping Complete Index (85/2666)-----------------------------------------------
# Business Analyst js
# Scraping URL: https://www.youtube.com/results?search_query=Course+js+js+Business Analyst
# Video divs found 10
# js.csv saved at: youtube_data\js.csv
# -----------------------------------------------Scraping Complete Index (86/2666)-----------------------------------------------
# Business Analyst kafka
# Scraping URL: https://www.youtube.com/results?search_query=Course+kafka+kafka+Business Analyst
# Video divs found 12
# kafka.csv saved at: youtube_data\kafka.csv
# -----------------------------------------------Scraping Complete Index (87/2666)-----------------------------------------------
# Business Analyst kubernetes
# Scraping URL: https://www.youtube.com/results?search_query=Course+kubernetes+kubernetes+Business Analyst
# Video divs found 12
# kubernetes.csv saved at: youtube_data\kubernetes.csv
# -----------------------------------------------Scraping Complete Index (88/2666)-----------------------------------------------
# Business Analyst linux
# Scraping URL: https://www.youtube.com/results?search_query=Course+linux+linux+Business Analyst
# Video divs found 20
# linux.csv saved at: youtube_data\linux.csv
# -----------------------------------------------Scraping Complete Index (89/2666)-----------------------------------------------
# Business Analyst machine learning
# Scraping URL: https://www.youtube.com/results?search_query=Course+machine+learning+machine+learning+Business Analyst
# Video divs found 20
# machine learning.csv saved at: youtube_data\machine learning.csv
# -----------------------------------------------Scraping Complete Index (90/2666)-----------------------------------------------
# Business Analyst market research
# Scraping URL: https://www.youtube.com/results?search_query=Course+market+research+market+research+Business Analyst
# Video divs found 18
# market research.csv saved at: youtube_data\market research.csv
# -----------------------------------------------Scraping Complete Index (91/2666)-----------------------------------------------
# Business Analyst mdx
# Scraping URL: https://www.youtube.com/results?search_query=Course+mdx+mdx+Business Analyst
# Video divs found 20
# mdx.csv saved at: youtube_data\mdx.csv
# -----------------------------------------------Scraping Complete Index (92/2666)-----------------------------------------------
# Business Analyst mes - manufacturing execution system
# Scraping URL: https://www.youtube.com/results?search_query=Course+mes+-+manufacturing+execution+system+mes+-+manufacturing+execution+system+Business Analyst
# Video divs found 19
# mes - manufacturing execution system.csv saved at: youtube_data\mes - manufacturing execution system.csv
# -----------------------------------------------Scraping Complete Index (93/2666)-----------------------------------------------
# Business Analyst microsoft access
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+access+microsoft+access+Business Analyst
# Video divs found 12
# microsoft access.csv saved at: youtube_data\microsoft access.csv
# -----------------------------------------------Scraping Complete Index (94/2666)-----------------------------------------------
# Business Analyst microsoft excel
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+excel+microsoft+excel+Business Analyst
# Video divs found 16
# microsoft excel.csv saved at: youtube_data\microsoft excel.csv
# -----------------------------------------------Scraping Complete Index (95/2666)-----------------------------------------------
# Business Analyst microsoft office
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+office+microsoft+office+Business Analyst
# Video divs found 19
# microsoft office.csv saved at: youtube_data\microsoft office.csv
# -----------------------------------------------Scraping Complete Index (96/2666)-----------------------------------------------
# Business Analyst microsoft office products
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+office+products+microsoft+office+products+Business Analyst
# Video divs found 18
# microsoft office products.csv saved at: youtube_data\microsoft office products.csv
# -----------------------------------------------Scraping Complete Index (97/2666)-----------------------------------------------
# Business Analyst microsoft office suite
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+office+suite+microsoft+office+suite+Business Analyst
# Video divs found 17
# microsoft office suite.csv saved at: youtube_data\microsoft office suite.csv
# -----------------------------------------------Scraping Complete Index (98/2666)-----------------------------------------------
# Business Analyst microsoft powerpoint
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+powerpoint+microsoft+powerpoint+Business Analyst
# Video divs found 20
# microsoft powerpoint.csv saved at: youtube_data\microsoft powerpoint.csv
# -----------------------------------------------Scraping Complete Index (99/2666)-----------------------------------------------
# Business Analyst microsoft project
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+project+microsoft+project+Business Analyst
# Video divs found 5
# microsoft project.csv saved at: youtube_data\microsoft project.csv
# -----------------------------------------------Scraping Complete Index (100/2666)-----------------------------------------------
# Business Analyst microsoft sql
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+sql+microsoft+sql+Business Analyst
# Video divs found 19
# microsoft sql.csv saved at: youtube_data\microsoft sql.csv
# -----------------------------------------------Scraping Complete Index (101/2666)-----------------------------------------------
# Business Analyst microsoft sql server
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+sql+server+microsoft+sql+server+Business Analyst
# Video divs found 20
# microsoft sql server.csv saved at: youtube_data\microsoft sql server.csv
# -----------------------------------------------Scraping Complete Index (102/2666)-----------------------------------------------
# Business Analyst microsoft visio
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+visio+microsoft+visio+Business Analyst
# Video divs found 16
# microsoft visio.csv saved at: youtube_data\microsoft visio.csv
# -----------------------------------------------Scraping Complete Index (103/2666)-----------------------------------------------
# Business Analyst microsoft word
# Scraping URL: https://www.youtube.com/results?search_query=Course+microsoft+word+microsoft+word+Business Analyst
# Video divs found 20
# microsoft word.csv saved at: youtube_data\microsoft word.csv
# -----------------------------------------------Scraping Complete Index (104/2666)-----------------------------------------------
# Business Analyst microstrategy
# Scraping URL: https://www.youtube.com/results?search_query=Course+microstrategy+microstrategy+Business Analyst
# Video divs found 20
# microstrategy.csv saved at: youtube_data\microstrategy.csv
# -----------------------------------------------Scraping Complete Index (105/2666)-----------------------------------------------
# Business Analyst mii - manufacturing intelligence and integration
# Scraping URL: https://www.youtube.com/results?search_query=Course+mii+-+manufacturing+intelligence+and+integration+mii+-+manufacturing+intelligence+and+integration+Business Analyst
# Video divs found 20
# mii - manufacturing intelligence and integration.csv saved at: youtube_data\mii - manufacturing intelligence and integration.csv
# -----------------------------------------------Scraping Complete Index (106/2666)-----------------------------------------------
# Business Analyst ms access
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+access+ms+access+Business Analyst
# Video divs found 11
# ms access.csv saved at: youtube_data\ms access.csv
# -----------------------------------------------Scraping Complete Index (107/2666)-----------------------------------------------
# Business Analyst ms excel
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+excel+ms+excel+Business Analyst
# Video divs found 14
# ms excel.csv saved at: youtube_data\ms excel.csv
# -----------------------------------------------Scraping Complete Index (108/2666)-----------------------------------------------
# Business Analyst ms office
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+office+ms+office+Business Analyst
# Video divs found 18
# ms office.csv saved at: youtube_data\ms office.csv
# -----------------------------------------------Scraping Complete Index (109/2666)-----------------------------------------------
# Business Analyst ms office suite
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+office+suite+ms+office+suite+Business Analyst
# Video divs found 16
# ms office suite.csv saved at: youtube_data\ms office suite.csv
# -----------------------------------------------Scraping Complete Index (110/2666)-----------------------------------------------
# Business Analyst ms powerpoint
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+powerpoint+ms+powerpoint+Business Analyst
# Video divs found 19
# ms powerpoint.csv saved at: youtube_data\ms powerpoint.csv
# -----------------------------------------------Scraping Complete Index (111/2666)-----------------------------------------------
# Business Analyst ms project
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+project+ms+project+Business Analyst
# Video divs found 17
# ms project.csv saved at: youtube_data\ms project.csv
# -----------------------------------------------Scraping Complete Index (112/2666)-----------------------------------------------
# Business Analyst ms sql server
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+sql+server+ms+sql+server+Business Analyst
# Video divs found 19
# ms sql server.csv saved at: youtube_data\ms sql server.csv
# -----------------------------------------------Scraping Complete Index (113/2666)-----------------------------------------------
# Business Analyst ms visio
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+visio+ms+visio+Business Analyst
# Video divs found 16
# ms visio.csv saved at: youtube_data\ms visio.csv
# -----------------------------------------------Scraping Complete Index (114/2666)-----------------------------------------------
# Business Analyst ms word
# Scraping URL: https://www.youtube.com/results?search_query=Course+ms+word+ms+word+Business Analyst
# Video divs found 18
# ms word.csv saved at: youtube_data\ms word.csv
# -----------------------------------------------Scraping Complete Index (115/2666)-----------------------------------------------
# Business Analyst mysql
# Scraping URL: https://www.youtube.com/results?search_query=Course+mysql+mysql+Business Analyst
# Video divs found 19
# mysql.csv saved at: youtube_data\mysql.csv
# -----------------------------------------------Scraping Complete Index (116/2666)-----------------------------------------------
# Business Analyst node
# Scraping URL: https://www.youtube.com/results?search_query=Course+node+node+Business Analyst
# Video divs found 19
# node.csv saved at: youtube_data\node.csv
# -----------------------------------------------Scraping Complete Index (117/2666)-----------------------------------------------
# Business Analyst obiee
# Scraping URL: https://www.youtube.com/results?search_query=Course+obiee+obiee+Business Analyst
# Video divs found 18
# obiee.csv saved at: youtube_data\obiee.csv
# -----------------------------------------------Scraping Complete Index (118/2666)-----------------------------------------------
# Business Analyst oracle
# Scraping URL: https://www.youtube.com/results?search_query=Course+oracle+oracle+Business Analyst
# Video divs found 19
# oracle.csv saved at: youtube_data\oracle.csv
# -----------------------------------------------Scraping Complete Index (119/2666)-----------------------------------------------
# Business Analyst oracle database
# Scraping URL: https://www.youtube.com/results?search_query=Course+oracle+database+oracle+database+Business Analyst
# Video divs found 9
# oracle database.csv saved at: youtube_data\oracle database.csv
# -----------------------------------------------Scraping Complete Index (120/2666)-----------------------------------------------
# Business Analyst oracle ebs
# Scraping URL: https://www.youtube.com/results?search_query=Course+oracle+ebs+oracle+ebs+Business Analyst
# Video divs found 15
# oracle ebs.csv saved at: youtube_data\oracle ebs.csv
# -----------------------------------------------Scraping Complete Index (121/2666)-----------------------------------------------
# Business Analyst oracle exadata
# Scraping URL: https://www.youtube.com/results?search_query=Course+oracle+exadata+oracle+exadata+Business Analyst
# Video divs found 20
# oracle exadata.csv saved at: youtube_data\oracle exadata.csv
# -----------------------------------------------Scraping Complete Index (122/2666)-----------------------------------------------
# Business Analyst oracle sql
# Scraping URL: https://www.youtube.com/results?search_query=Course+oracle+sql+oracle+sql+Business Analyst
# Video divs found 16
# oracle sql.csv saved at: youtube_data\oracle sql.csv
# -----------------------------------------------Scraping Complete Index (123/2666)-----------------------------------------------
# Business Analyst pandas
# Scraping URL: https://www.youtube.com/results?search_query=Course+pandas+pandas+Business Analyst
# Video divs found 15
# pandas.csv saved at: youtube_data\pandas.csv
# -----------------------------------------------Scraping Complete Index (124/2666)-----------------------------------------------
# Business Analyst peoplesoft
# Scraping URL: https://www.youtube.com/results?search_query=Course+peoplesoft+peoplesoft+Business Analyst
# Video divs found 20
# peoplesoft.csv saved at: youtube_data\peoplesoft.csv
# -----------------------------------------------Scraping Complete Index (125/2666)-----------------------------------------------
# Business Analyst performance tuning
# Scraping URL: https://www.youtube.com/results?search_query=Course+performance+tuning+performance+tuning+Business Analyst
# Video divs found 15
# performance tuning.csv saved at: youtube_data\performance tuning.csv
# -----------------------------------------------Scraping Complete Index (126/2666)-----------------------------------------------
# Business Analyst perl
# Scraping URL: https://www.youtube.com/results?search_query=Course+perl+perl+Business Analyst
# Video divs found 20
# perl.csv saved at: youtube_data\perl.csv
# -----------------------------------------------Scraping Complete Index (127/2666)-----------------------------------------------
# Business Analyst pl/sql
# Scraping URL: https://www.youtube.com/results?search_query=Course+pl/sql+pl/sql+Business Analyst
# Video divs found 18
# pl_sql.csv saved at: youtube_data\pl_sql.csv
# -----------------------------------------------Scraping Complete Index (128/2666)-----------------------------------------------
# Business Analyst power bi
# Scraping URL: https://www.youtube.com/results?search_query=Course+power+bi+power+bi+Business Analyst
# Video divs found 18
# power bi.csv saved at: youtube_data\power bi.csv
# -----------------------------------------------Scraping Complete Index (129/2666)-----------------------------------------------
# Business Analyst powerpoint
# Scraping URL: https://www.youtube.com/results?search_query=Course+powerpoint+powerpoint+Business Analyst
# Video divs found 18
# powerpoint.csv saved at: youtube_data\powerpoint.csv
# -----------------------------------------------Scraping Complete Index (130/2666)-----------------------------------------------
# Business Analyst powershell
# Scraping URL: https://www.youtube.com/results?search_query=Course+powershell+powershell+Business Analyst
# Video divs found 14
# powershell.csv saved at: youtube_data\powershell.csv
# -----------------------------------------------Scraping Complete Index (131/2666)-----------------------------------------------
# Business Analyst programming
# Scraping URL: https://www.youtube.com/results?search_query=Course+programming+programming+Business Analyst
# Video divs found 17
# programming.csv saved at: youtube_data\programming.csv
# -----------------------------------------------Scraping Complete Index (132/2666)-----------------------------------------------
# Business Analyst project management
# Scraping URL: https://www.youtube.com/results?search_query=Course+project+management+project+management+Business Analyst
# Video divs found 6
# project management.csv saved at: youtube_data\project management.csv
# -----------------------------------------------Scraping Complete Index (133/2666)-----------------------------------------------
# Business Analyst python
# Scraping URL: https://www.youtube.com/results?search_query=Course+python+python+Business Analyst
# Video divs found 2
# python.csv saved at: youtube_data\python.csv
# -----------------------------------------------Scraping Complete Index (134/2666)-----------------------------------------------
# Business Analyst qlikview
# Scraping URL: https://www.youtube.com/results?search_query=Course+qlikview+qlikview+Business Analyst
# Video divs found 11
# qlikview.csv saved at: youtube_data\qlikview.csv
# -----------------------------------------------Scraping Complete Index (135/2666)-----------------------------------------------
# Business Analyst quality assurance
# Scraping URL: https://www.youtube.com/results?search_query=Course+quality+assurance+quality+assurance+Business Analyst
# Video divs found 10
# quality assurance.csv saved at: youtube_data\quality assurance.csv
# -----------------------------------------------Scraping Complete Index (136/2666)-----------------------------------------------
# Business Analyst r
# Scraping URL: https://www.youtube.com/results?search_query=Course+r+r+Business Analyst
# Video divs found 20
# r.csv saved at: youtube_data\r.csv
# -----------------------------------------------Scraping Complete Index (137/2666)-----------------------------------------------
# Business Analyst relational database
# Scraping URL: https://www.youtube.com/results?search_query=Course+relational+database+relational+database+Business Analyst
# Video divs found 10
# relational database.csv saved at: youtube_data\relational database.csv
# -----------------------------------------------Scraping Complete Index (138/2666)-----------------------------------------------
# Business Analyst requirements gathering
# Scraping URL: https://www.youtube.com/results?search_query=Course+requirements+gathering+requirements+gathering+Business Analyst
# Video divs found 4
# requirements gathering.csv saved at: youtube_data\requirements gathering.csv
# ...
# Web Developer swagger
# Scraping URL: https://www.youtube.com/results?search_query=Course+swagger+swagger+Web Developer
# Video divs found 0
# swagger.csv saved at: youtube_data\swagger.csv
# -----------------------------------------------Scraping Complete Index (2618/2666)-----------------------------------------------
# Web Developer swift
# Scraping URL: https://www.youtube.com/results?search_query=Course+swift+swift+Web Developer
# Video divs found 0
# swift.csv saved at: youtube_data\swift.csv
# -----------------------------------------------Scraping Complete Index (2619/2666)-----------------------------------------------
# Web Developer t-sql
# Scraping URL: https://www.youtube.com/results?search_query=Course+t-sql+t-sql+Web Developer
# Video divs found 0
# t-sql.csv saved at: youtube_data\t-sql.csv
# -----------------------------------------------Scraping Complete Index (2620/2666)-----------------------------------------------
# Web Developer talend
# Scraping URL: https://www.youtube.com/results?search_query=Course+talend+talend+Web Developer
# Video divs found 0
# talend.csv saved at: youtube_data\talend.csv
# -----------------------------------------------Scraping Complete Index (2621/2666)-----------------------------------------------
# Web Developer tdd
# Scraping URL: https://www.youtube.com/results?search_query=Course+tdd+tdd+Web Developer
# Video divs found 0
# tdd.csv saved at: youtube_data\tdd.csv
# -----------------------------------------------Scraping Complete Index (2622/2666)-----------------------------------------------
# Web Developer team foundation server
# Scraping URL: https://www.youtube.com/results?search_query=Course+team+foundation+server+team+foundation+server+Web Developer
# Video divs found 0
# team foundation server.csv saved at: youtube_data\team foundation server.csv
# -----------------------------------------------Scraping Complete Index (2623/2666)-----------------------------------------------
# Web Developer tensorflow
# Scraping URL: https://www.youtube.com/results?search_query=Course+tensorflow+tensorflow+Web Developer
# Video divs found 0
# tensorflow.csv saved at: youtube_data\tensorflow.csv
# -----------------------------------------------Scraping Complete Index (2624/2666)-----------------------------------------------
# Web Developer test driven development
# Scraping URL: https://www.youtube.com/results?search_query=Course+test+driven+development+test+driven+development+Web Developer
# Video divs found 0
# test driven development.csv saved at: youtube_data\test driven development.csv
# -----------------------------------------------Scraping Complete Index (2625/2666)-----------------------------------------------
# Web Developer test driven development (tdd)
# Scraping URL: https://www.youtube.com/results?search_query=Course+test+driven+development+(tdd)+test+driven+development+(tdd)+Web Developer
# Video divs found 0
# test driven development (tdd).csv saved at: youtube_data\test driven development (tdd).csv
# -----------------------------------------------Scraping Complete Index (2626/2666)-----------------------------------------------
# Web Developer test-driven development
# Scraping URL: https://www.youtube.com/results?search_query=Course+test-driven+development+test-driven+development+Web Developer
# Video divs found 0
# test-driven development.csv saved at: youtube_data\test-driven development.csv
# -----------------------------------------------Scraping Complete Index (2627/2666)-----------------------------------------------
# Web Developer testing
# Scraping URL: https://www.youtube.com/results?search_query=Course+testing+testing+Web Developer
# Video divs found 0
# testing.csv saved at: youtube_data\testing.csv
# -----------------------------------------------Scraping Complete Index (2628/2666)-----------------------------------------------
# Web Developer tfs
# Scraping URL: https://www.youtube.com/results?search_query=Course+tfs+tfs+Web Developer
# Video divs found 0
# tfs.csv saved at: youtube_data\tfs.csv
# -----------------------------------------------Scraping Complete Index (2629/2666)-----------------------------------------------
# Web Developer tomcat
# Scraping URL: https://www.youtube.com/results?search_query=Course+tomcat+tomcat+Web Developer
# Video divs found 0
# tomcat.csv saved at: youtube_data\tomcat.csv
# -----------------------------------------------Scraping Complete Index (2630/2666)-----------------------------------------------
# Web Developer typescript
# Scraping URL: https://www.youtube.com/results?search_query=Course+typescript+typescript+Web Developer
# Video divs found 0
# typescript.csv saved at: youtube_data\typescript.csv
# -----------------------------------------------Scraping Complete Index (2631/2666)-----------------------------------------------
# Web Developer ui
# Scraping URL: https://www.youtube.com/results?search_query=Course+ui+ui+Web Developer
# Video divs found 0
# ui.csv saved at: youtube_data\ui.csv
# -----------------------------------------------Scraping Complete Index (2632/2666)-----------------------------------------------
# Web Developer ui design
# Scraping URL: https://www.youtube.com/results?search_query=Course+ui+design+ui+design+Web Developer
# Video divs found 0
# ui design.csv saved at: youtube_data\ui design.csv
# -----------------------------------------------Scraping Complete Index (2633/2666)-----------------------------------------------
# Web Developer unit testing
# Scraping URL: https://www.youtube.com/results?search_query=Course+unit+testing+unit+testing+Web Developer
# Video divs found 0
# unit testing.csv saved at: youtube_data\unit testing.csv
# -----------------------------------------------Scraping Complete Index (2634/2666)-----------------------------------------------
# Web Developer unix
# Scraping URL: https://www.youtube.com/results?search_query=Course+unix+unix+Web Developer
# Video divs found 0
# unix.csv saved at: youtube_data\unix.csv
# -----------------------------------------------Scraping Complete Index (2635/2666)-----------------------------------------------
# Web Developer unix shell scripting
# Scraping URL: https://www.youtube.com/results?search_query=Course+unix+shell+scripting+unix+shell+scripting+Web Developer
# Video divs found 0
# unix shell scripting.csv saved at: youtube_data\unix shell scripting.csv
# -----------------------------------------------Scraping Complete Index (2636/2666)-----------------------------------------------
# Web Developer unix/linux
# Scraping URL: https://www.youtube.com/results?search_query=Course+unix/linux+unix/linux+Web Developer
# Video divs found 0
# unix_linux.csv saved at: youtube_data\unix_linux.csv
# -----------------------------------------------Scraping Complete Index (2637/2666)-----------------------------------------------
# Web Developer user interface design
# Scraping URL: https://www.youtube.com/results?search_query=Course+user+interface+design+user+interface+design+Web Developer
# Video divs found 0
# user interface design.csv saved at: youtube_data\user interface design.csv
# -----------------------------------------------Scraping Complete Index (2638/2666)-----------------------------------------------
# Web Developer ux design
# Scraping URL: https://www.youtube.com/results?search_query=Course+ux+design+ux+design+Web Developer
# Video divs found 0
# ux design.csv saved at: youtube_data\ux design.csv
# -----------------------------------------------Scraping Complete Index (2639/2666)-----------------------------------------------
# Web Developer vb
# Scraping URL: https://www.youtube.com/results?search_query=Course+vb+vb+Web Developer
# Video divs found 0
# vb.csv saved at: youtube_data\vb.csv
# -----------------------------------------------Scraping Complete Index (2640/2666)-----------------------------------------------
# Web Developer vb.net
# Scraping URL: https://www.youtube.com/results?search_query=Course+vb.net+vb.net+Web Developer
# Video divs found 0
# vb.net.csv saved at: youtube_data\vb.net.csv
# -----------------------------------------------Scraping Complete Index (2641/2666)-----------------------------------------------
# Web Developer vba
# Scraping URL: https://www.youtube.com/results?search_query=Course+vba+vba+Web Developer
# Video divs found 0
# vba.csv saved at: youtube_data\vba.csv
# -----------------------------------------------Scraping Complete Index (2642/2666)-----------------------------------------------
# Web Developer version control
# Scraping URL: https://www.youtube.com/results?search_query=Course+version+control+version+control+Web Developer
# Video divs found 0
# version control.csv saved at: youtube_data\version control.csv
# -----------------------------------------------Scraping Complete Index (2643/2666)-----------------------------------------------
# Web Developer visual studio
# Scraping URL: https://www.youtube.com/results?search_query=Course+visual+studio+visual+studio+Web Developer
# Video divs found 0
# visual studio.csv saved at: youtube_data\visual studio.csv
# -----------------------------------------------Scraping Complete Index (2644/2666)-----------------------------------------------
# Web Developer visualforce
# Scraping URL: https://www.youtube.com/results?search_query=Course+visualforce+visualforce+Web Developer
# Video divs found 0
# visualforce.csv saved at: youtube_data\visualforce.csv
# -----------------------------------------------Scraping Complete Index (2645/2666)-----------------------------------------------
# Web Developer vue
# Scraping URL: https://www.youtube.com/results?search_query=Course+vue+vue+Web Developer
# Video divs found 0
# vue.csv saved at: youtube_data\vue.csv
# -----------------------------------------------Scraping Complete Index (2646/2666)-----------------------------------------------
# Web Developer wcf
# Scraping URL: https://www.youtube.com/results?search_query=Course+wcf+wcf+Web Developer
# Video divs found 0
# wcf.csv saved at: youtube_data\wcf.csv
# -----------------------------------------------Scraping Complete Index (2647/2666)-----------------------------------------------
# Web Developer web api
# Scraping URL: https://www.youtube.com/results?search_query=Course+web+api+web+api+Web Developer
# Video divs found 0
# web api.csv saved at: youtube_data\web api.csv
# -----------------------------------------------Scraping Complete Index (2648/2666)-----------------------------------------------
# Web Developer web applications
# Scraping URL: https://www.youtube.com/results?search_query=Course+web+applications+web+applications+Web Developer
# Video divs found 0
# web applications.csv saved at: youtube_data\web applications.csv
# -----------------------------------------------Scraping Complete Index (2649/2666)-----------------------------------------------
# Web Developer web development
# Scraping URL: https://www.youtube.com/results?search_query=Course+web+development+web+development+Web Developer
# Video divs found 0
# web development.csv saved at: youtube_data\web development.csv
# -----------------------------------------------Scraping Complete Index (2650/2666)-----------------------------------------------
# Web Developer web forms
# Scraping URL: https://www.youtube.com/results?search_query=Course+web+forms+web+forms+Web Developer
# Video divs found 0
# web forms.csv saved at: youtube_data\web forms.csv
# -----------------------------------------------Scraping Complete Index (2651/2666)-----------------------------------------------
# Web Developer web service
# Scraping URL: https://www.youtube.com/results?search_query=Course+web+service+web+service+Web Developer
# Video divs found 0
# web service.csv saved at: youtube_data\web service.csv
# -----------------------------------------------Scraping Complete Index (2652/2666)-----------------------------------------------
# Web Developer web services
# Scraping URL: https://www.youtube.com/results?search_query=Course+web+services+web+services+Web Developer
# Video divs found 0
# web services.csv saved at: youtube_data\web services.csv
# -----------------------------------------------Scraping Complete Index (2653/2666)-----------------------------------------------
# Web Developer webapi
# Scraping URL: https://www.youtube.com/results?search_query=Course+webapi+webapi+Web Developer
# Video divs found 0
# webapi.csv saved at: youtube_data\webapi.csv
# -----------------------------------------------Scraping Complete Index (2654/2666)-----------------------------------------------
# Web Developer webpack
# Scraping URL: https://www.youtube.com/results?search_query=Course+webpack+webpack+Web Developer
# Video divs found 0
# webpack.csv saved at: youtube_data\webpack.csv
# -----------------------------------------------Scraping Complete Index (2655/2666)-----------------------------------------------
# Web Developer websocket
# Scraping URL: https://www.youtube.com/results?search_query=Course+websocket+websocket+Web Developer
# Video divs found 0
# websocket.csv saved at: youtube_data\websocket.csv
# -----------------------------------------------Scraping Complete Index (2656/2666)-----------------------------------------------
# Web Developer window
# Scraping URL: https://www.youtube.com/results?search_query=Course+window+window+Web Developer
# Video divs found 0
# window.csv saved at: youtube_data\window.csv
# -----------------------------------------------Scraping Complete Index (2657/2666)-----------------------------------------------
# Web Developer winform
# Scraping URL: https://www.youtube.com/results?search_query=Course+winform+winform+Web Developer
# Video divs found 0
# winform.csv saved at: youtube_data\winform.csv
# -----------------------------------------------Scraping Complete Index (2658/2666)-----------------------------------------------
# Web Developer wireframes
# Scraping URL: https://www.youtube.com/results?search_query=Course+wireframes+wireframes+Web Developer
# Video divs found 0
# wireframes.csv saved at: youtube_data\wireframes.csv
# -----------------------------------------------Scraping Complete Index (2659/2666)-----------------------------------------------
# Web Developer wordpress
# Scraping URL: https://www.youtube.com/results?search_query=Course+wordpress+wordpress+Web Developer
# Video divs found 0
# wordpress.csv saved at: youtube_data\wordpress.csv
# -----------------------------------------------Scraping Complete Index (2660/2666)-----------------------------------------------
# Web Developer wpf
# Scraping URL: https://www.youtube.com/results?search_query=Course+wpf+wpf+Web Developer
# Video divs found 0
# wpf.csv saved at: youtube_data\wpf.csv
# -----------------------------------------------Scraping Complete Index (2661/2666)-----------------------------------------------
# Web Developer xamarin
# Scraping URL: https://www.youtube.com/results?search_query=Course+xamarin+xamarin+Web Developer
# Video divs found 0
# xamarin.csv saved at: youtube_data\xamarin.csv
# -----------------------------------------------Scraping Complete Index (2662/2666)-----------------------------------------------
# Web Developer xcode
# Scraping URL: https://www.youtube.com/results?search_query=Course+xcode+xcode+Web Developer
# Video divs found 0
# xcode.csv saved at: youtube_data\xcode.csv
# -----------------------------------------------Scraping Complete Index (2663/2666)-----------------------------------------------
# Web Developer xhtml
# Scraping URL: https://www.youtube.com/results?search_query=Course+xhtml+xhtml+Web Developer
# Video divs found 0
# xhtml.csv saved at: youtube_data\xhtml.csv
# -----------------------------------------------Scraping Complete Index (2664/2666)-----------------------------------------------
# Web Developer xml
# Scraping URL: https://www.youtube.com/results?search_query=Course+xml+xml+Web Developer
# Video divs found 0
# xml.csv saved at: youtube_data\xml.csv
# -----------------------------------------------Scraping Complete Index (2665/2666)-----------------------------------------------
# Web Developer xom
# Scraping URL: https://www.youtube.com/results?search_query=Course+xom+xom+Web Developer
# Video divs found 0
# xom.csv saved at: youtube_data\xom.csv
# -----------------------------------------------Scraping Complete Index (2666/2666)-----------------------------------------------
